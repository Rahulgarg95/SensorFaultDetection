# %%
import os
import boto3
import datetime

# %%
AWS_KEY_ID='AKIAR5FCHCJSPNQHVLNM'
AWS_SECRET='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'

# %%
s3 = boto3.client("s3", 
                  region_name='ap-south-1', 
                  aws_access_key_id=AWS_KEY_ID, 
                  aws_secret_access_key=AWS_SECRET)

# %%
bucket_response = s3.list_buckets()

# %%
bucket_response
# Out:
# {'ResponseMetadata': {'RequestId': '4C9968064F13879D',
#   'HostId': 'CCiSV81QNGDF+csNTogRKm9gmbTvWo8UuMtm3J4u+WQUjrV3+8KN986GM9BMBA/HZdI9GHgX6NQ=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'CCiSV81QNGDF+csNTogRKm9gmbTvWo8UuMtm3J4u+WQUjrV3+8KN986GM9BMBA/HZdI9GHgX6NQ=',
#    'x-amz-request-id': '4C9968064F13879D',
#    'date': 'Thu, 04 Mar 2021 07:48:03 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'sensor-fault-detection',
#    'CreationDate': datetime.datetime(2021, 3, 2, 3, 49, 54, tzinfo=tzutc())}],
#  'Owner': {'ID': 'b1365e24f3c0942326945292bf00c1999534706f277fc223546104456193605c'}}

# %%
buckets = bucket_response["Buckets"]

# %%
bucket_name=buckets[0]['Name']

# %%
object_name=s3.list_objects(Bucket=bucket_name)['Contents'][0]['Key']

# %%
object_name
# Out:
# 'Prediction_Raw_Files_Validated/'

# %%
s3.upload_file('Training_Batch_Files/Wafer_15010_130532.csv', bucket_name, object_name + 'Wafer_15010_130532.csv')

# %%
obj=s3.get_object(Bucket=bucket_name,Key='Training_Batch_Files/Wafer_15010_130532.csv')

# %%
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(obj['Body'].read()))

# %%
df.head()
# Out:
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-800   3002.22   2462.06  2202.1222  1833.3772    1.8005       100
# 1  Wafer-500   3047.28   2186.06  2235.0556  1302.6607    1.6347       100
# 2  Wafer-501   3076.81   2158.75  2208.2334  1517.0152    1.0980       100
# 3  Wafer-502   2951.62   2511.92  2253.5111  1397.5060    0.9660       100
# 4  Wafer-503   2930.42   2505.17  2235.0556  1302.6607    1.6347       100
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-581  Sensor-582  Sensor-583  \
# 0   95.8500    0.1242    1.5173  ...         NaN         NaN      0.5021
# 1  109.9856    0.1230    1.4619  ...         NaN         NaN      0.4998
# 2  110.1900    0.1247    1.4357  ...      0.0090     64.2405      0.5016
# 3  109.7611    0.1210    1.5527  ...      0.0081      0.0000      0.4953
# 4  109.9856    0.1230    1.4588  ...         NaN         NaN      0.4958
#
#    Sensor-584  Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  \
# 0      0.0071      0.0024      1.4182      0.0545      0.0184      0.0055
# 1      0.0131      0.0033      2.6229      0.0222      0.0182      0.0060
# 2      0.0152      0.0040      3.0319      0.0465      0.0299      0.0090
# 3      0.0105      0.0037      2.1266     -0.0012      0.0252      0.0081
# 4      0.0111      0.0033      2.2296     -0.0012      0.0252      0.0081
#
#    Sensor-590
# 0     33.7876
# 1     81.9472
# 2     64.2405
# 3      0.0000
# 4      0.0000
#
# [5 rows x 591 columns]

# %%
s3.put_object(Bucket=bucket_name, Key=('Prediction_Raw_Files_Validated'+'/'))
# Out:
# {'ResponseMetadata': {'RequestId': 'C0E16B5D74EF1866',
#   'HostId': 'T6m5m/Z4NtoAF+8g8LDZCatxK5uiy7HCem0rBNQZxfFiMNbiz98j7GcFCklsYa6737X7we7OahQ=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'T6m5m/Z4NtoAF+8g8LDZCatxK5uiy7HCem0rBNQZxfFiMNbiz98j7GcFCklsYa6737X7we7OahQ=',
#    'x-amz-request-id': 'C0E16B5D74EF1866',
#    'date': 'Thu, 04 Mar 2021 07:48:07 GMT',
#    'etag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"d41d8cd98f00b204e9800998ecf8427e"'}

# %%
#x_s3 = boto3.resource('s3')
copy_source = {
    'Bucket': bucket_name,
    'Key': 'Training_Batch_Files/Wafer_15010_130532.csv'
}
s3.copy(copy_source, bucket_name, 'tmp_folder/tmp_20210304/Wafer_15010_130532.csv')

# %%
s3.list_objects(Bucket=bucket_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'BRBTET4MDW7GBYAJ',
#   'HostId': 'qMEUlMSqZr5GReZN3EMaGcVfvoGAG+LmRqrji5klbk2MMLicUVILnzVa0kq7JZ07LXkNFN6g3D0=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'qMEUlMSqZr5GReZN3EMaGcVfvoGAG+LmRqrji5klbk2MMLicUVILnzVa0kq7JZ07LXkNFN6g3D0=',
#    'x-amz-request-id': 'BRBTET4MDW7GBYAJ',
#    'date': 'Thu, 04 Mar 2021 07:48:08 GMT',
#    'x-amz-bucket-region': 'ap-south-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Marker': '',
#  'Contents': [{'Key': 'Prediction_Raw_Files_Validated/',
#    'LastModified': datetime.datetime(2021, 3, 4, 7, 48, 7, tzinfo=tzutc()),
#    'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'Size': 0,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': 'b1365e24f3c0942326945292bf00c1999534706f277fc223546104456193605c'}},
#   {'Key': 'Prediction_Raw_Files_Validated/Wafer_15010_130532.csv',
#    'LastModified': datetime.datetime(2021, 3, 4, 7, 48, 7, tzinfo=tzutc()),
#    'ETag': '"2dae6309bdb71304f04e5c122c54e2d8"',
#    'Size': 342221,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': 'b1365e24f3c0942326945292bf00c1999534706f277fc223546104456193605c'}},
#   {'Key': 'Prediction_Raw_Files_Validated/sample.txt',
#    'LastModified': datetime.datetime(2021, 3, 3, 19, 37, 11, tzinfo=tzutc()),
#    'ETag': '"0ec018c36f315bc1ad22e4eb1b37c8ae"',
#    'Size': 22,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': 'b1365e24f3c0942326945292bf00c1999534706f277fc223546104456193605c'}},
#   {'Key': 'Training_Batch_Files/Wafer_15010_130532.csv',
#    'LastModified': datetime.datetime(2021, 3, 2, 18, 1, 35, tzinfo=tzutc()),
#    'ETag': '"2dae6309bdb71304f04e5c122c54e2d8"',
#    'Size': 342221,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': 'b1365e24f3c0942326945292bf00c1999534706f277fc223546104456193605c'}}],
#  'Name': 'sensor-fault-detection',
#  'Prefix': '',
#  'MaxKeys': 1000,
#  'EncodingType': 'url'}

# %%
paginator=s3.get_paginator('list_objects_v2')

# %%
result = paginator.paginate(Bucket=bucket_name,StartAfter='Prediction_Raw_Files_Validated/')

# %%
for page in result:
    if('Contents' in page):
        for key in page[ "Contents" ]:
            keyString = key[ "Key" ]
            print(keyString)
# Out:
# Prediction_Raw_Files_Validated/Wafer_15010_130532.csv
# Prediction_Raw_Files_Validated/sample.txt
# Training_Batch_Files/Wafer_15010_130532.csv

# %%
response = s3.list_objects(Bucket=bucket_name, Prefix="Prediction_Raw_Files_Validated/")

# %%
request_files = response["Contents"]
for file in request_files:
    if('.csv' in file['Key']):
        print(file['Key'])
        obj = s3.get_object(Bucket=bucket_name, Key=file["Key"])
        obj_df = pd.read_csv(obj["Body"])
        print(obj_df.shape)
# Out:
# Prediction_Raw_Files_Validated/Wafer_07012020_000000.csv
# (100, 591)

# %%
contents=s3.list_objects(Bucket=bucket_name,Prefix='Prediction_Raw_Files_Validated/')['Contents']

# %%
for data in contents:
    print(data)
# Out:
# {'Key': 'Prediction_Raw_Files_Validated/', 'LastModified': datetime.datetime(2021, 3, 4, 7, 48, 7, tzinfo=tzutc()), 'ETag': '"d41d8cd98f00b204e9800998ecf8427e"', 'Size': 0, 'StorageClass': 'STANDARD', 'Owner': {'ID': 'b1365e24f3c0942326945292bf00c1999534706f277fc223546104456193605c'}}
# {'Key': 'Prediction_Raw_Files_Validated/Wafer_15010_130532.csv', 'LastModified': datetime.datetime(2021, 3, 4, 7, 48, 7, tzinfo=tzutc()), 'ETag': '"2dae6309bdb71304f04e5c122c54e2d8"', 'Size': 342221, 'StorageClass': 'STANDARD', 'Owner': {'ID': 'b1365e24f3c0942326945292bf00c1999534706f277fc223546104456193605c'}}
# {'Key': 'Prediction_Raw_Files_Validated/sample.txt', 'LastModified': datetime.datetime(2021, 3, 3, 19, 37, 11, tzinfo=tzutc()), 'ETag': '"0ec018c36f315bc1ad22e4eb1b37c8ae"', 'Size': 22, 'StorageClass': 'STANDARD', 'Owner': {'ID': 'b1365e24f3c0942326945292bf00c1999534706f277fc223546104456193605c'}}

# %%
s3.put_object(Body='THis is a sample2 file',Bucket=bucket_name, Key='Prediction_Raw_Files_Validated/sample.txt')
# Out:
# {'ResponseMetadata': {'RequestId': '4270BD88D8EDCDDC',
#   'HostId': 'D92yvDhUXDSeazFLABmp93jl5uB8S2lD+IvElcGlwjfXJw7NCrPe9NYlTMUUqirhwcPkkArbZl8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'D92yvDhUXDSeazFLABmp93jl5uB8S2lD+IvElcGlwjfXJw7NCrPe9NYlTMUUqirhwcPkkArbZl8=',
#    'x-amz-request-id': '4270BD88D8EDCDDC',
#    'date': 'Thu, 04 Mar 2021 07:48:09 GMT',
#    'etag': '"0ec018c36f315bc1ad22e4eb1b37c8ae"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"0ec018c36f315bc1ad22e4eb1b37c8ae"'}

# %%
obj=s3.get_object(Bucket=bucket_name,Key='Prediction_Raw_Files_Validated/sample.txt')

# %%
obj['Body'].read()
# Out:
# b'THis is a sample2 file'

# %%
s3.delete_object(Bucket=bucket_name,Key='Prediction_Raw_Files_Validated/')
# Out:
# {'ResponseMetadata': {'RequestId': '8916A1E5DBD3268D',
#   'HostId': 'hTTXsA+LdfrtAb3JVCY1rXBSU2VyQvK3MebShHZrlxUe/YpezS/F9jzYliLL0mbCuPjX3dcVjTU=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'hTTXsA+LdfrtAb3JVCY1rXBSU2VyQvK3MebShHZrlxUe/YpezS/F9jzYliLL0mbCuPjX3dcVjTU=',
#    'x-amz-request-id': '8916A1E5DBD3268D',
#    'date': 'Thu, 04 Mar 2021 10:14:06 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %%
cont=s3.list_objects(Bucket=bucket_name)['Contents']

# %%
master_list=[[1,2],[3,4]]

# %%
df=pd.DataFrame(master_list,columns=['col1','col2'])

# %%
df
# Out:
#    col1  col2
# 0     1     2
# 1     3     4

# %%
res_s3 = boto3.resource('s3',region_name='ap-south-1', 
                  aws_access_key_id=AWS_KEY_ID, 
                  aws_secret_access_key=AWS_SECRET)

# %%
res_s3
# Out:
# s3.ServiceResource()

# %%
csv_buffer = io.StringIO()
df.to_csv(csv_buffer)

# %%
csv_buffer

# %%
res_s3.Object(bucket_name, 'Prediction_Raw_Files_Validated/df.csv').put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': '7T0K5V1H4T0KFG1M',
#   'HostId': 'rErSFbf+AiXTBR4DEkCTDEw1NfPbGCTbI4EgeJY4Tw4zix5t2MKlDnzGEgvIghXck0zPIgg75Dc=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'rErSFbf+AiXTBR4DEkCTDEw1NfPbGCTbI4EgeJY4Tw4zix5t2MKlDnzGEgvIghXck0zPIgg75Dc=',
#    'x-amz-request-id': '7T0K5V1H4T0KFG1M',
#    'date': 'Thu, 04 Mar 2021 10:57:56 GMT',
#    'etag': '"060fa7e2f381e5e61c7762da062ffec8"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"060fa7e2f381e5e61c7762da062ffec8"'}

# %%
bucket_n=res_s3.Bucket(bucket_name)

# %%
bucket_n.objects.filter(Prefix="Bad_Raw_Pred_Raw_Files_Validated/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'BBDFF665D15E7F16',
#    'HostId': 'zR9D2dHzF5MIKaic4TI24itjD1lO6osmezA8SGVxJN8eTfid7QcLFRWg1wvmvAswuk0v0ybDxJM=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'zR9D2dHzF5MIKaic4TI24itjD1lO6osmezA8SGVxJN8eTfid7QcLFRWg1wvmvAswuk0v0ybDxJM=',
#     'x-amz-request-id': 'BBDFF665D15E7F16',
#     'date': 'Thu, 04 Mar 2021 12:54:17 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'Bad_Raw_Pred_Raw_Files_Validated/'}]}]

# %%
import os
import pandas as pd
import boto3
import io
from application_logging.logger import App_Logger

class AwsStorageManagement:

    def __init__(self):
        self.AWS_KEY_ID = 'AKIAR5FCHCJSPNQHVLNM'  # AWS KEY ID
        self.AWS_SECRET = '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'  # AWS SECRET KEY

        #Creating a s3 client to access resources
        self.s3 = boto3.client("s3",
                          region_name='ap-south-1',
                          aws_access_key_id=self.AWS_KEY_ID,
                          aws_secret_access_key=self.AWS_SECRET)

        #Create a resource object
        self.res_s3 = boto3.resource('s3',
                                    region_name='ap-south-1',
                                    aws_access_key_id=self.AWS_KEY_ID,
                                    aws_secret_access_key=self.AWS_SECRET)
        self.bucket_name='sensor-fault-detection'
        self.logger = App_Logger()
        self.file = open("Training_Logs/awsBucketManagementLogs.txt", 'a+')

    def isFolderPresent(self,folder_name):
        """
        :param folder_name: folder_name to search in bucket
        :return: True if given folder_name is present in AWS S3
        """
        contents=self.s3.list_objects(Bucket=self.bucket_name,Delimiter='/')['CommonPrefixes']
        for data in contents:
            if folder_name in data['Prefix']:
                return True
        else:
            return False

    def isFilePresent(self,folder_name,file_name):
        """
        :param folder_name: Folder name in which file to be checked
        :param file_name: File Name to be checked
        :return: Return status of presence of given file
        """
        contents=self.s3.list_objects(Bucket=self.bucket_name,Prefix=folder_name+'/')['Contents']
        for data in contents:
            if file_name in data['Key']:
                return True
            else:
                return False

    def createS3Directory(self,folder_name):
        """

        :param folder_name: folder name to be create
        :return: None
        """
        if self.isFolderPresent(folder_name):
            message='Folder: ' + folder_name + ' already present in bucket'
            self.logger.log(self.file,message)
        else:
            self.s3.put_object(Bucket=self.bucket_name, Key=(folder_name+'/'))
            message = 'Required Folder: ' + folder_name + ' created'
            self.logger.log(self.file, message)

    def uploadFiles(self,source_dir,dest_dir,file_name=''):
        """
        :param source_dir: Folder in local system from where file to be uploaded
        :param dest_dir: Folder in S3 bucket to which file to be uploaded
        :param file_name: File to be uploaded
        :return:
        """
        if not self.isFolderPresent(dest_dir):
            self.createS3Directory(dest_dir)
        if file_name == '':
            message='Single File Not provided hence bulk upload mode'
            self.logger.log(self.file, message)
            file_list=os.listdir(source_dir)
            for file_n in file_list:
                if not self.isFilePresent(dest_dir,file_n):
                    self.s3.upload_file(os.path.join(source_dir,file_n), self.bucket_name,dest_dir+'/'+file_n)
            self.logger.log(self.file, 'Bulk file upload done')
        else:
            self.s3.upload_file(os.path.join(source_dir, file_name), self.bucket_name, dest_dir+'/'+file_name)

    def csvToDataframe(self,folder_name,file_name=''):
        """

        :param folder_name:
        :param file_name:
        :return: Returns dataframe
        """
        if file_name == '':
            message='File Name Not Provided, loading all files from ' + folder_name + ' to dataframe'
            self.logger.log(self.file,message)
            response = self.s3.list_objects(Bucket=self.bucket_name, Prefix=folder_name+"/")
            request_files = response["Contents"]
            cnt=0
            for file in request_files:
                if '.csv' in file['Key']:
                    #print(file['Key'])
                    obj = self.s3.get_object(Bucket=self.bucket_name, Key=file["Key"])
                    tmp_df = pd.read_csv(io.BytesIO(obj['Body'].read()))
                    print(tmp_df.columns)
                    if cnt==0:
                        obj_df=tmp_df.copy()
                        cnt+=1
                    else:
                        obj_df=pd.concat([obj_df,tmp_df])
            message='Dataframe created from folder: ' + folder_name + '.Total Records: ' + str(obj_df.shape[0]) + ' Total Columns: ' + str(obj_df.shape[0])
            self.logger.log(self.file, message)
            return obj_df
        else:
            obj = self.s3.get_object(Bucket=self.bucket_name, Key=folder_name+'/'+file_name)
            obj_df = pd.read_csv(io.BytesIO(obj['Body'].read()))
            return obj_df

    def saveObject(self,folder_name,file_name,object_name):
        """

        :param folder_name: Folder name to be accessed
        :param file_name: File to be created
        :param object_name: Object to be loaded
        :return: None
        """
        self.s3.put_object(Body=object, Bucket=self.bucket_name,
                      Key=folder_name+'/'+file_name)
        message='Object Loaded to File: ' + file_name
        self.logger.log(self.file, message)

    def loadObject(self,folder_name,file_name):
        """

        :param folder_name: Folder containing file
        :param file_name: File to be loaded
        :return: object loaded
        """
        obj = self.s3.get_object(Bucket=self.bucket_name, Key=folder_name+'/'+file_name)
        object_name=obj['Body'].read()
        return object_name

    def listDirFiles(self,folder_name):
        """

        :param folder_name: Folder from which files to be listed
        :return: list with file_names
        """
        response = self.s3.list_objects(Bucket=self.bucket_name, Prefix=folder_name + "/")
        request_files = response["Contents"]
        file_list=[]
        for file in request_files:
            if not file['Key'].split('/')[-1]=='':
                file_n=file['Key'].split('/')[-1]
                file_list.append(file_n)
        return file_list

    def copyFileToFolder(self,source_folder,target_folder,file_name=''):
        """

        :param source_folder: Copy files from dir
        :param target_folder: Copy files to dir
        :param file_name: File_name
        :return:
        """
        if file_name=='':
            file_list=self.listDirFiles(source_folder)
            for file_n in file_list:
                print(file_n)
                copy_source = {
                    'Bucket': self.bucket_name,
                    'Key': source_folder+'/'+file_n
                }
                self.s3.copy(copy_source, self.bucket_name, target_folder+'/'+file_n)
        else:
            copy_source = {
                'Bucket': self.bucket_name,
                'Key': source_folder+'/'+file_name
            }
            self.s3.copy(copy_source, self.bucket_name, target_folder+'/'+file_name)

    def deleteFile(self,folder_name,file_name=''):
        """

        :param folder_name: Folder Name containing files to delete
        :param file_name: File Name to delete
        :return: None
        """
        if file_name=='':
            file_list = self.listDirFiles(folder_name)
            for file_n in file_list:
                self.s3.delete_object(Bucket=self.bucket_name,Key=folder_name+'/'+file_n)
        else:
            self.s3.delete_object(Bucket=self.bucket_name, Key=folder_name+'/'+file_name)

    def deleteDirectory(self,folder_name):
        """

        :param folder_name:
        :return:
        """
        bucket_n = self.res_s3.Bucket(self.bucket_name)
        if self.isFolderPresent(folder_name):
            bucket_n.objects.filter(Prefix=folder_name+'/').delete()

    def moveFileToFolder(self, source_folder, target_folder, file_name=''):
        """

        :param source_folder:
        :param target_folder:
        :param file_name:
        :return:
        """
        if file_name=='':
            self.copyFileToFolder(source_folder,target_folder)
            self.deleteFile(source_folder)
        else:
            self.copyFileToFolder(source_folder, target_folder,file_name)
            self.deleteFile(source_folder,file_name)



    def saveDataframeToCsv(self,folder_name,file_name,df):
        """

        :param folder_name: Folder Name where file needs to be placed
        :param file_name: File Name to which dataframe is stored
        :param df: Dataframe to be loaded
        :return: None
        """
        csv_buffer = io.StringIO()
        df.to_csv(csv_buffer)
        self.res_s3.Object(self.bucket_name, folder_name+'/'+file_name).put(Body=csv_buffer.getvalue())

# %%
aws_obj=AwsStorageManagement()

# %%
aws_obj.isFolderPresent('Training_Batch_Files')
# Out:
# True

# %%
aws_obj.uploadFiles('Training_Batch_Files','Training_Batch_Files')

# %%
aws_obj.listDirFiles('Training_Batch_Files')
# Out:
# ['Wafer12_20012.csv',
#  'Wafer_07012020_000000.csv',
#  'Wafer_07012020_223345.csv',
#  'Wafer_08012020_120000.csv',
#  'Wafer_10012020_131534.csv',
#  'Wafer_11012020_151432.csv',
#  'Wafer_12012020_111.csv',
#  'Wafer_12012020_111213.csv',
#  'Wafer_13012020_141000.csv',
#  'Wafer_14012020_113045.csv',
#  'Wafer_15010_130532.csv',
#  'Wafer_15012020_130532.csv',
#  'Wafer_18012020_121532.csv',
#  'Wafer_19012020_141432.csv',
#  'Wafer_20012020_135132.csv',
#  'Wafer_21012020_143634.csv',
#  'Wafer_22012020_173245.csv',
#  'Wafer_23012020_163456.csv',
#  'Wafer_24012020_150121.csv',
#  'Wafer_25012020_142112.csv',
#  'Wafer_fault_detection.csv',
#  'Wafer_text_130532.csv',
#  'Waferdefault_15010_130532.csv',
#  'wafer_07012020_041011.csv',
#  'wafer_13012020_090817.csv',
#  'wafer_16012020_051629.csv',
#  'wafer_16012020_134553.csv',
#  'wafer_17012020_125434.csv',
#  'wafer_20012020_090819.csv',
#  'wafer_20022020_090716.csv',
#  'wafer_21012020_080913.csv',
#  'wafer_22022020_041119.csv',
#  'wafer_23012020_011008.csv',
#  'wafer_23012020_041211.csv',
#  'wafer_27012020_080911.csv',
#  'wafer_28012020_051011.csv',
#  'wafer_28012020_090817.csv',
#  'wafer_28042020_031911.csv',
#  'wafer_29012020_050617.csv',
#  'wafer_29012020_060756.csv',
#  'wafer_31012020_090811.csv']

# %%
aws_obj.copyFileToFolder('Training_Batch_Files','Prediction_Raw_Files_Validated','Wafer_07012020_000000.csv')

# %%
aws_obj.deleteFile('Prediction_Raw_Files_Validated')

# %%
aws_obj.deleteDirectory('Good_Raw_Pred_Raw_Files_Validated')

# %%
aws_obj.moveFileToFolder('Training_Batch_Files','Prediction_Raw_Files_Validated','Wafer_07012020_000000.csv')

# %%
for col in df:
    print(col)
# Out:
# col1
# col2

# %%
import json

# %%
json.loads(df.T.to_json()).values()
# Out:
# dict_values([{'col1': 1, 'col2': 2}, {'col1': 3, 'col2': 4}])

# %%
obj_df.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-581', 'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585',
#        'Sensor-586', 'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590'],
#       dtype='object', length=591)

# %%
obj_df=obj_df.rename(columns={'Unnamed: 0':'Wafer'})

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://rahul95:rahul123@python-mongo.enkic.mongodb.net/waferFaultDB?retryWrites=true&w=majority")
db = client.waferFaultDB
COLLECTION_NAME = "Good_Raw_Data"
collection = db[COLLECTION_NAME]

# %%
collection1=db['schema']

# %%
f=open('schema_training.json','r')
train_schema=json.loads(f.read())

# %%
#train_schema['Schema_Type']='Training'

# %%
train_schema
# Out:
# {'SampleFileName': 'wafer_08012020_120000.csv',
#  'LengthOfDateStampInFile': 8,
#  'LengthOfTimeStampInFile': 6,
#  'NumberofColumns': 592,
#  'ColName': {'Wafer': 'varchar',
#   'Sensor - 1': ' float',
#   'Sensor - 2': ' float',
#   'Sensor - 3': ' float',
#   'Sensor - 4': ' float',
#   'Sensor - 5': ' float',
#   'Sensor - 6': ' float',
#   'Sensor - 7': ' float',
#   'Sensor - 8': ' float',
#   'Sensor - 9': ' float',
#   'Sensor - 10': ' float',
#   'Sensor - 11': ' float',
#   'Sensor - 12': ' float',
#   'Sensor - 13': ' float',
#   'Sensor - 14': ' float',
#   'Sensor - 15': ' float',
#   'Sensor - 16': ' float',
#   'Sensor - 17': ' float',
#   'Sensor - 18': ' float',
#   'Sensor - 19': ' float',
#   'Sensor - 20': ' float',
#   'Sensor - 21': ' float',
#   'Sensor - 22': ' float',
#   'Sensor - 23': ' float',
#   'Sensor - 24': ' float',
#   'Sensor - 25': ' float',
#   'Sensor - 26': ' float',
#   'Sensor - 27': ' float',
#   'Sensor - 28': ' float',
#   'Sensor - 29': ' float',
#   'Sensor - 30': ' float',
#   'Sensor - 31': ' float',
#   'Sensor - 32': ' float',
#   'Sensor - 33': ' float',
#   'Sensor - 34': ' float',
#   'Sensor - 35': ' float',
#   'Sensor - 36': ' float',
#   'Sensor - 37': ' float',
#   'Sensor - 38': ' float',
#   'Sensor - 39': ' float',
#   'Sensor - 40': ' float',
#   'Sensor - 41': ' float',
#   'Sensor - 42': ' float',
#   'Sensor - 43': ' float',
#   'Sensor - 44': ' float',
#   'Sensor - 45': ' float',
#   'Sensor - 46': ' float',
#   'Sensor - 47': ' float',
#   'Sensor - 48': ' float',
#   'Sensor - 49': ' float',
#   'Sensor - 50': ' float',
#   'Sensor - 51': ' float',
#   'Sensor - 52': ' float',
#   'Sensor - 53': ' float',
#   'Sensor - 54': ' float',
#   'Sensor - 55': ' float',
#   'Sensor - 56': ' float',
#   'Sensor - 57': ' float',
#   'Sensor - 58': ' float',
#   'Sensor - 59': ' float',
#   'Sensor - 60': ' float',
#   'Sensor - 61': ' float',
#   'Sensor - 62': ' float',
#   'Sensor - 63': ' float',
#   'Sensor - 64': ' float',
#   'Sensor - 65': ' float',
#   'Sensor - 66': ' float',
#   'Sensor - 67': ' float',
#   'Sensor - 68': ' float',
#   'Sensor - 69': ' float',
#   'Sensor - 70': ' float',
#   'Sensor - 71': ' float',
#   'Sensor - 72': ' float',
#   'Sensor - 73': ' float',
#   'Sensor - 74': ' float',
#   'Sensor - 75': ' float',
#   'Sensor - 76': ' float',
#   'Sensor - 77': ' float',
#   'Sensor - 78': ' float',
#   'Sensor - 79': ' float',
#   'Sensor - 80': ' float',
#   'Sensor - 81': ' float',
#   'Sensor - 82': ' float',
#   'Sensor - 83': ' float',
#   'Sensor - 84': ' float',
#   'Sensor - 85': ' float',
#   'Sensor - 86': ' float',
#   'Sensor - 87': ' float',
#   'Sensor - 88': ' float',
#   'Sensor - 89': ' float',
#   'Sensor - 90': ' float',
#   'Sensor - 91': ' float',
#   'Sensor - 92': ' float',
#   'Sensor - 93': ' float',
#   'Sensor - 94': ' float',
#   'Sensor - 95': ' float',
#   'Sensor - 96': ' float',
#   'Sensor - 97': ' float',
#   'Sensor - 98': ' float',
#   'Sensor - 99': ' float',
#   'Sensor - 100': ' float',
#   'Sensor - 101': ' float',
#   'Sensor - 102': ' float',
#   'Sensor - 103': ' float',
#   'Sensor - 104': ' float',
#   'Sensor - 105': ' float',
#   'Sensor - 106': ' float',
#   'Sensor - 107': ' float',
#   'Sensor - 108': ' float',
#   'Sensor - 109': ' float',
#   'Sensor - 110': ' float',
#   'Sensor - 111': ' float',
#   'Sensor - 112': ' float',
#   'Sensor - 113': ' float',
#   'Sensor - 114': ' float',
#   'Sensor - 115': ' float',
#   'Sensor - 116': ' float',
#   'Sensor - 117': ' float',
#   'Sensor - 118': ' float',
#   'Sensor - 119': ' float',
#   'Sensor - 120': ' float',
#   'Sensor - 121': ' float',
#   'Sensor - 122': ' float',
#   'Sensor - 123': ' float',
#   'Sensor - 124': ' float',
#   'Sensor - 125': ' float',
#   'Sensor - 126': ' float',
#   'Sensor - 127': ' float',
#   'Sensor - 128': ' float',
#   'Sensor - 129': ' float',
#   'Sensor - 130': ' float',
#   'Sensor - 131': ' float',
#   'Sensor - 132': ' float',
#   'Sensor - 133': ' float',
#   'Sensor - 134': ' float',
#   'Sensor - 135': ' float',
#   'Sensor - 136': ' float',
#   'Sensor - 137': ' float',
#   'Sensor - 138': ' float',
#   'Sensor - 139': ' float',
#   'Sensor - 140': ' float',
#   'Sensor - 141': ' float',
#   'Sensor - 142': ' float',
#   'Sensor - 143': ' float',
#   'Sensor - 144': ' float',
#   'Sensor - 145': ' float',
#   'Sensor - 146': ' float',
#   'Sensor - 147': ' float',
#   'Sensor - 148': ' float',
#   'Sensor - 149': ' float',
#   'Sensor - 150': ' float',
#   'Sensor - 151': ' float',
#   'Sensor - 152': ' float',
#   'Sensor - 153': ' float',
#   'Sensor - 154': ' float',
#   'Sensor - 155': ' float',
#   'Sensor - 156': ' float',
#   'Sensor - 157': ' float',
#   'Sensor - 158': ' float',
#   'Sensor - 159': ' float',
#   'Sensor - 160': ' float',
#   'Sensor - 161': ' float',
#   'Sensor - 162': ' float',
#   'Sensor - 163': ' float',
#   'Sensor - 164': ' float',
#   'Sensor - 165': ' float',
#   'Sensor - 166': ' float',
#   'Sensor - 167': ' float',
#   'Sensor - 168': ' float',
#   'Sensor - 169': ' float',
#   'Sensor - 170': ' float',
#   'Sensor - 171': ' float',
#   'Sensor - 172': ' float',
#   'Sensor - 173': ' float',
#   'Sensor - 174': ' float',
#   'Sensor - 175': ' float',
#   'Sensor - 176': ' float',
#   'Sensor - 177': ' float',
#   'Sensor - 178': ' float',
#   'Sensor - 179': ' float',
#   'Sensor - 180': ' float',
#   'Sensor - 181': ' float',
#   'Sensor - 182': ' float',
#   'Sensor - 183': ' float',
#   'Sensor - 184': ' float',
#   'Sensor - 185': ' float',
#   'Sensor - 186': ' float',
#   'Sensor - 187': ' float',
#   'Sensor - 188': ' float',
#   'Sensor - 189': ' float',
#   'Sensor - 190': ' float',
#   'Sensor - 191': ' float',
#   'Sensor - 192': ' float',
#   'Sensor - 193': ' float',
#   'Sensor - 194': ' float',
#   'Sensor - 195': ' float',
#   'Sensor - 196': ' float',
#   'Sensor - 197': ' float',
#   'Sensor - 198': ' float',
#   'Sensor - 199': ' float',
#   'Sensor - 200': ' float',
#   'Sensor - 201': ' float',
#   'Sensor - 202': ' float',
#   'Sensor - 203': ' float',
#   'Sensor - 204': ' float',
#   'Sensor - 205': ' float',
#   'Sensor - 206': ' float',
#   'Sensor - 207': ' float',
#   'Sensor - 208': ' float',
#   'Sensor - 209': ' float',
#   'Sensor - 210': ' float',
#   'Sensor - 211': ' float',
#   'Sensor - 212': ' float',
#   'Sensor - 213': ' float',
#   'Sensor - 214': ' float',
#   'Sensor - 215': ' float',
#   'Sensor - 216': ' float',
#   'Sensor - 217': ' float',
#   'Sensor - 218': ' float',
#   'Sensor - 219': ' float',
#   'Sensor - 220': ' float',
#   'Sensor - 221': ' float',
#   'Sensor - 222': ' float',
#   'Sensor - 223': ' float',
#   'Sensor - 224': ' float',
#   'Sensor - 225': ' float',
#   'Sensor - 226': ' float',
#   'Sensor - 227': ' float',
#   'Sensor - 228': ' float',
#   'Sensor - 229': ' float',
#   'Sensor - 230': ' float',
#   'Sensor - 231': ' float',
#   'Sensor - 232': ' float',
#   'Sensor - 233': ' float',
#   'Sensor - 234': ' float',
#   'Sensor - 235': ' float',
#   'Sensor - 236': ' float',
#   'Sensor - 237': ' float',
#   'Sensor - 238': ' float',
#   'Sensor - 239': ' float',
#   'Sensor - 240': ' float',
#   'Sensor - 241': ' float',
#   'Sensor - 242': ' float',
#   'Sensor - 243': ' float',
#   'Sensor - 244': ' float',
#   'Sensor - 245': ' float',
#   'Sensor - 246': ' float',
#   'Sensor - 247': ' float',
#   'Sensor - 248': ' float',
#   'Sensor - 249': ' float',
#   'Sensor - 250': ' float',
#   'Sensor - 251': ' float',
#   'Sensor - 252': ' float',
#   'Sensor - 253': ' float',
#   'Sensor - 254': ' float',
#   'Sensor - 255': ' float',
#   'Sensor - 256': ' float',
#   'Sensor - 257': ' float',
#   'Sensor - 258': ' float',
#   'Sensor - 259': ' float',
#   'Sensor - 260': ' float',
#   'Sensor - 261': ' float',
#   'Sensor - 262': ' float',
#   'Sensor - 263': ' float',
#   'Sensor - 264': ' float',
#   'Sensor - 265': ' float',
#   'Sensor - 266': ' float',
#   'Sensor - 267': ' float',
#   'Sensor - 268': ' float',
#   'Sensor - 269': ' float',
#   'Sensor - 270': ' float',
#   'Sensor - 271': ' float',
#   'Sensor - 272': ' float',
#   'Sensor - 273': ' float',
#   'Sensor - 274': ' float',
#   'Sensor - 275': ' float',
#   'Sensor - 276': ' float',
#   'Sensor - 277': ' float',
#   'Sensor - 278': ' float',
#   'Sensor - 279': ' float',
#   'Sensor - 280': ' float',
#   'Sensor - 281': ' float',
#   'Sensor - 282': ' float',
#   'Sensor - 283': ' float',
#   'Sensor - 284': ' float',
#   'Sensor - 285': ' float',
#   'Sensor - 286': ' float',
#   'Sensor - 287': ' float',
#   'Sensor - 288': ' float',
#   'Sensor - 289': ' float',
#   'Sensor - 290': ' float',
#   'Sensor - 291': ' float',
#   'Sensor - 292': ' float',
#   'Sensor - 293': ' float',
#   'Sensor - 294': ' float',
#   'Sensor - 295': ' float',
#   'Sensor - 296': ' float',
#   'Sensor - 297': ' float',
#   'Sensor - 298': ' float',
#   'Sensor - 299': ' float',
#   'Sensor - 300': ' float',
#   'Sensor - 301': ' float',
#   'Sensor - 302': ' float',
#   'Sensor - 303': ' float',
#   'Sensor - 304': ' float',
#   'Sensor - 305': ' float',
#   'Sensor - 306': ' float',
#   'Sensor - 307': ' float',
#   'Sensor - 308': ' float',
#   'Sensor - 309': ' float',
#   'Sensor - 310': ' float',
#   'Sensor - 311': ' float',
#   'Sensor - 312': ' float',
#   'Sensor - 313': ' float',
#   'Sensor - 314': ' float',
#   'Sensor - 315': ' float',
#   'Sensor - 316': ' float',
#   'Sensor - 317': ' float',
#   'Sensor - 318': ' float',
#   'Sensor - 319': ' float',
#   'Sensor - 320': ' float',
#   'Sensor - 321': ' float',
#   'Sensor - 322': ' float',
#   'Sensor - 323': ' float',
#   'Sensor - 324': ' float',
#   'Sensor - 325': ' float',
#   'Sensor - 326': ' float',
#   'Sensor - 327': ' float',
#   'Sensor - 328': ' float',
#   'Sensor - 329': ' float',
#   'Sensor - 330': ' float',
#   'Sensor - 331': ' float',
#   'Sensor - 332': ' float',
#   'Sensor - 333': ' float',
#   'Sensor - 334': ' float',
#   'Sensor - 335': ' float',
#   'Sensor - 336': ' float',
#   'Sensor - 337': ' float',
#   'Sensor - 338': ' float',
#   'Sensor - 339': ' float',
#   'Sensor - 340': ' float',
#   'Sensor - 341': ' float',
#   'Sensor - 342': ' float',
#   'Sensor - 343': ' float',
#   'Sensor - 344': ' float',
#   'Sensor - 345': ' float',
#   'Sensor - 346': ' float',
#   'Sensor - 347': ' float',
#   'Sensor - 348': ' float',
#   'Sensor - 349': ' float',
#   'Sensor - 350': ' float',
#   'Sensor - 351': ' float',
#   'Sensor - 352': ' float',
#   'Sensor - 353': ' float',
#   'Sensor - 354': ' float',
#   'Sensor - 355': ' float',
#   'Sensor - 356': ' float',
#   'Sensor - 357': ' float',
#   'Sensor - 358': ' float',
#   'Sensor - 359': ' float',
#   'Sensor - 360': ' float',
#   'Sensor - 361': ' float',
#   'Sensor - 362': ' float',
#   'Sensor - 363': ' float',
#   'Sensor - 364': ' float',
#   'Sensor - 365': ' float',
#   'Sensor - 366': ' float',
#   'Sensor - 367': ' float',
#   'Sensor - 368': ' float',
#   'Sensor - 369': ' float',
#   'Sensor - 370': ' float',
#   'Sensor - 371': ' float',
#   'Sensor - 372': ' float',
#   'Sensor - 373': ' float',
#   'Sensor - 374': ' float',
#   'Sensor - 375': ' float',
#   'Sensor - 376': ' float',
#   'Sensor - 377': ' float',
#   'Sensor - 378': ' float',
#   'Sensor - 379': ' float',
#   'Sensor - 380': ' float',
#   'Sensor - 381': ' float',
#   'Sensor - 382': ' float',
#   'Sensor - 383': ' float',
#   'Sensor - 384': ' float',
#   'Sensor - 385': ' float',
#   'Sensor - 386': ' float',
#   'Sensor - 387': ' float',
#   'Sensor - 388': ' float',
#   'Sensor - 389': ' float',
#   'Sensor - 390': ' float',
#   'Sensor - 391': ' float',
#   'Sensor - 392': ' float',
#   'Sensor - 393': ' float',
#   'Sensor - 394': ' float',
#   'Sensor - 395': ' float',
#   'Sensor - 396': ' float',
#   'Sensor - 397': ' float',
#   'Sensor - 398': ' float',
#   'Sensor - 399': ' float',
#   'Sensor - 400': ' float',
#   'Sensor - 401': ' float',
#   'Sensor - 402': ' float',
#   'Sensor - 403': ' float',
#   'Sensor - 404': ' float',
#   'Sensor - 405': ' float',
#   'Sensor - 406': ' float',
#   'Sensor - 407': ' float',
#   'Sensor - 408': ' float',
#   'Sensor - 409': ' float',
#   'Sensor - 410': ' float',
#   'Sensor - 411': ' float',
#   'Sensor - 412': ' float',
#   'Sensor - 413': ' float',
#   'Sensor - 414': ' float',
#   'Sensor - 415': ' float',
#   'Sensor - 416': ' float',
#   'Sensor - 417': ' float',
#   'Sensor - 418': ' float',
#   'Sensor - 419': ' float',
#   'Sensor - 420': ' float',
#   'Sensor - 421': ' float',
#   'Sensor - 422': ' float',
#   'Sensor - 423': ' float',
#   'Sensor - 424': ' float',
#   'Sensor - 425': ' float',
#   'Sensor - 426': ' float',
#   'Sensor - 427': ' float',
#   'Sensor - 428': ' float',
#   'Sensor - 429': ' float',
#   'Sensor - 430': ' float',
#   'Sensor - 431': ' float',
#   'Sensor - 432': ' float',
#   'Sensor - 433': ' float',
#   'Sensor - 434': ' float',
#   'Sensor - 435': ' float',
#   'Sensor - 436': ' float',
#   'Sensor - 437': ' float',
#   'Sensor - 438': ' float',
#   'Sensor - 439': ' float',
#   'Sensor - 440': ' float',
#   'Sensor - 441': ' float',
#   'Sensor - 442': ' float',
#   'Sensor - 443': ' float',
#   'Sensor - 444': ' float',
#   'Sensor - 445': ' float',
#   'Sensor - 446': ' float',
#   'Sensor - 447': ' float',
#   'Sensor - 448': ' float',
#   'Sensor - 449': ' float',
#   'Sensor - 450': ' float',
#   'Sensor - 451': ' float',
#   'Sensor - 452': ' float',
#   'Sensor - 453': ' float',
#   'Sensor - 454': ' float',
#   'Sensor - 455': ' float',
#   'Sensor - 456': ' float',
#   'Sensor - 457': ' float',
#   'Sensor - 458': ' float',
#   'Sensor - 459': ' float',
#   'Sensor - 460': ' float',
#   'Sensor - 461': ' float',
#   'Sensor - 462': ' float',
#   'Sensor - 463': ' float',
#   'Sensor - 464': ' float',
#   'Sensor - 465': ' float',
#   'Sensor - 466': ' float',
#   'Sensor - 467': ' float',
#   'Sensor - 468': ' float',
#   'Sensor - 469': ' float',
#   'Sensor - 470': ' float',
#   'Sensor - 471': ' float',
#   'Sensor - 472': ' float',
#   'Sensor - 473': ' float',
#   'Sensor - 474': ' float',
#   'Sensor - 475': ' float',
#   'Sensor - 476': ' float',
#   'Sensor - 477': ' float',
#   'Sensor - 478': ' float',
#   'Sensor - 479': ' float',
#   'Sensor - 480': ' float',
#   'Sensor - 481': ' float',
#   'Sensor - 482': ' float',
#   'Sensor - 483': ' float',
#   'Sensor - 484': ' float',
#   'Sensor - 485': ' float',
#   'Sensor - 486': ' float',
#   'Sensor - 487': ' float',
#   'Sensor - 488': ' float',
#   'Sensor - 489': ' float',
#   'Sensor - 490': ' float',
#   'Sensor - 491': ' float',
#   'Sensor - 492': ' float',
#   'Sensor - 493': ' float',
#   'Sensor - 494': ' float',
#   'Sensor - 495': ' float',
#   'Sensor - 496': ' float',
#   'Sensor - 497': ' float',
#   'Sensor - 498': ' float',
#   'Sensor - 499': ' float',
#   'Sensor - 500': ' float',
#   'Sensor - 501': ' float',
#   'Sensor - 502': ' float',
#   'Sensor - 503': ' float',
#   'Sensor - 504': ' float',
#   'Sensor - 505': ' float',
#   'Sensor - 506': ' float',
#   'Sensor - 507': ' float',
#   'Sensor - 508': ' float',
#   'Sensor - 509': ' float',
#   'Sensor - 510': ' float',
#   'Sensor - 511': ' float',
#   'Sensor - 512': ' float',
#   'Sensor - 513': ' float',
#   'Sensor - 514': ' float',
#   'Sensor - 515': ' float',
#   'Sensor - 516': ' float',
#   'Sensor - 517': ' float',
#   'Sensor - 518': ' float',
#   'Sensor - 519': ' float',
#   'Sensor - 520': ' float',
#   'Sensor - 521': ' float',
#   'Sensor - 522': ' float',
#   'Sensor - 523': ' float',
#   'Sensor - 524': ' float',
#   'Sensor - 525': ' float',
#   'Sensor - 526': ' float',
#   'Sensor - 527': ' float',
#   'Sensor - 528': ' float',
#   'Sensor - 529': ' float',
#   'Sensor - 530': ' float',
#   'Sensor - 531': ' float',
#   'Sensor - 532': ' float',
#   'Sensor - 533': ' float',
#   'Sensor - 534': ' float',
#   'Sensor - 535': ' float',
#   'Sensor - 536': ' float',
#   'Sensor - 537': ' float',
#   'Sensor - 538': ' float',
#   'Sensor - 539': ' float',
#   'Sensor - 540': ' float',
#   'Sensor - 541': ' float',
#   'Sensor - 542': ' float',
#   'Sensor - 543': ' float',
#   'Sensor - 544': ' float',
#   'Sensor - 545': ' float',
#   'Sensor - 546': ' float',
#   'Sensor - 547': ' float',
#   'Sensor - 548': ' float',
#   'Sensor - 549': ' float',
#   'Sensor - 550': ' float',
#   'Sensor - 551': ' float',
#   'Sensor - 552': ' float',
#   'Sensor - 553': ' float',
#   'Sensor - 554': ' float',
#   'Sensor - 555': ' float',
#   'Sensor - 556': ' float',
#   'Sensor - 557': ' float',
#   'Sensor - 558': ' float',
#   'Sensor - 559': ' float',
#   'Sensor - 560': ' float',
#   'Sensor - 561': ' float',
#   'Sensor - 562': ' float',
#   'Sensor - 563': ' float',
#   'Sensor - 564': ' float',
#   'Sensor - 565': ' float',
#   'Sensor - 566': ' float',
#   'Sensor - 567': ' float',
#   'Sensor - 568': ' float',
#   'Sensor - 569': ' float',
#   'Sensor - 570': ' float',
#   'Sensor - 571': ' float',
#   'Sensor - 572': ' float',
#   'Sensor - 573': ' float',
#   'Sensor - 574': ' float',
#   'Sensor - 575': ' float',
#   'Sensor - 576': ' float',
#   'Sensor - 577': ' float',
#   'Sensor - 578': ' float',
#   'Sensor - 579': ' float',
#   'Sensor - 580': ' float',
#   'Sensor - 581': ' float',
#   'Sensor - 582': ' float',
#   'Sensor - 583': ' float',
#   'Sensor - 584': ' float',
#   'Sensor - 585': ' float',
#   'Sensor - 586': ' float',
#   'Sensor - 587': ' float',
#   'Sensor - 588': ' float',
#   'Sensor - 589': ' float',
#   'Sensor - 590': ' float',
#   'Output': 'Integer'}}

# %%
collection1.insert_one(train_schema)

# %%
collection1.find(train_schema).count()
# Out:
# <ipython-input-190-4859722d07dd>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   collection1.find(train_schema).count()
# 2

# %%
for x  in collection1.find(train_schema):
    print(len(x))
# Out:
# 6
# 7

# %%
records=list(json.loads(obj_df.T.to_json()).values())

# %%
collection.insert_many(records)

# %%
all_record=collection.find()

# %%
for idx, record in enumerate(all_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('604103f31a89d5420c5e95a2'), 'Wafer': 'Wafer-1400', 'Sensor-1': 3034.74, 'Sensor-2': 2458.9, 'Sensor-3': 2192.1889, 'Sensor-4': 1435.9611, 'Sensor-5': 2.387, 'Sensor-6': 100.0, 'Sensor-7': 107.3989, 'Sensor-8': 0.1229, 'Sensor-9': 1.5447, 'Sensor-10': 0.0036, 'Sensor-11': -0.0125, 'Sensor-12': 0.9757, 'Sensor-13': 201.9267, 'Sensor-14': 0, 'Sensor-15': 13.3326, 'Sensor-16': 406.3998, 'Sensor-17': 10.1672, 'Sensor-18': 0.9789, 'Sensor-19': 191.7594, 'Sensor-20': 12.5788, 'Sensor-21': 1.4082, 'Sensor-22': -5636.0, 'Sensor-23': 2556.5, 'Sensor-24': -7102.0, 'Sensor-25': -8231.5, 'Sensor-26': 1.287, 'Sensor-27': 2.0152, 'Sensor-28': 7.2467, 'Sensor-29': 73.0667, 'Sensor-30': 1.9444, 'Sensor-31': 0.1521, 'Sensor-32': 3.3759, 'Sensor-33': 85.2544, 'Sensor-34': 8.3675, 'Sensor-35': 50.2934, 'Sensor-36': 64.3032, 'Sensor-37': 49.7066, 'Sensor-38': 66.0584, 'Sensor-39': 86.8342, 'Sensor-40': 117.487, 'Sensor-41': 2.506, 'Sensor-42': 1.582, 'Sensor-43': 70, 'Sensor-44': 370.3327, 'Sensor-45': 9.792, 'Sensor-46': 144.5391, 'Sensor-47': 759.293, 'Sensor-48': 1.2714, 'Sensor-49': 136.2909, 'Sensor-50': 1, 'Sensor-51': 651.1627, 'Sensor-52': 206.9758, 'Sensor-53': 0, 'Sensor-54': 4.633, 'Sensor-55': 4.91, 'Sensor-56': 2873, 'Sensor-57': 0.9172, 'Sensor-58': 0.9435, 'Sensor-59': 4.4868, 'Sensor-60': -5.3264, 'Sensor-61': 369.3418, 'Sensor-62': 10.4104, 'Sensor-63': 119.2127, 'Sensor-64': 22.33, 'Sensor-65': 25.3264, 'Sensor-66': 36.1696, 'Sensor-67': 723.1234, 'Sensor-68': 0.5633, 'Sensor-69': 140.2782, 'Sensor-70': 1, 'Sensor-71': 628.8327, 'Sensor-72': 175.7635, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.0134, 'Sensor-77': 0.0297, 'Sensor-78': -0.0188, 'Sensor-79': -0.0485, 'Sensor-80': -0.0052, 'Sensor-81': -0.0267, 'Sensor-82': -0.0681, 'Sensor-83': -0.0466, 'Sensor-84': 7.1724, 'Sensor-85': 0.1338, 'Sensor-86': None, 'Sensor-87': 2.4303, 'Sensor-88': 0.9876, 'Sensor-89': 1884.7195, 'Sensor-90': 0.1643, 'Sensor-91': 10228.08, 'Sensor-92': -0.1515, 'Sensor-93': -0.0003, 'Sensor-94': -0.0037, 'Sensor-95': -0.0001, 'Sensor-96': 0.0001, 'Sensor-97': 0.1559, 'Sensor-98': 0, 'Sensor-99': -0.4195, 'Sensor-100': 0.0065, 'Sensor-101': 0.0002, 'Sensor-102': -0.0002, 'Sensor-103': 0.0606, 'Sensor-104': -0.0104, 'Sensor-105': -0.0001, 'Sensor-106': 0.0003, 'Sensor-107': 0.0036, 'Sensor-108': -0.0887, 'Sensor-109': 0.0343, 'Sensor-110': 0.982, 'Sensor-111': 98.8262, 'Sensor-112': 234.4062, 'Sensor-113': None, 'Sensor-114': 0.8537, 'Sensor-115': 0.0, 'Sensor-116': 886.7893, 'Sensor-117': 0.9898, 'Sensor-118': 58.3971, 'Sensor-119': 0.6068, 'Sensor-120': 0.9615, 'Sensor-121': 6.4011, 'Sensor-122': 15.72, 'Sensor-123': 2.398, 'Sensor-124': 15.71, 'Sensor-125': 15.73, 'Sensor-126': 0.9365, 'Sensor-127': 2.985, 'Sensor-128': 0.4108, 'Sensor-129': 3.398, 'Sensor-130': 0.3784, 'Sensor-131': 0.8741, 'Sensor-132': 1.0, 'Sensor-133': 2.2732, 'Sensor-134': 1000.1451, 'Sensor-135': 37.0354, 'Sensor-136': 77, 'Sensor-137': 177.2, 'Sensor-138': 96.6, 'Sensor-139': 62.1001, 'Sensor-140': 324.222, 'Sensor-141': 0.6996, 'Sensor-142': 0.0, 'Sensor-143': 4.57, 'Sensor-144': 0.0031, 'Sensor-145': 0.208, 'Sensor-146': 0.0386, 'Sensor-147': 0.0525, 'Sensor-148': 0.0089, 'Sensor-149': 9.4727, 'Sensor-150': 0, 'Sensor-151': 12.351, 'Sensor-152': 4.304, 'Sensor-153': 0.3304, 'Sensor-154': 0.0075, 'Sensor-155': 9.2106, 'Sensor-156': 0.26, 'Sensor-157': 0.0162, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 554, 'Sensor-161': 147, 'Sensor-162': 12727, 'Sensor-163': 15822, 'Sensor-164': 0.117, 'Sensor-165': 0.097, 'Sensor-166': 0.151, 'Sensor-167': 2.5, 'Sensor-168': 1.2, 'Sensor-169': 0.153, 'Sensor-170': 0.663, 'Sensor-171': 0.5344, 'Sensor-172': 0.1325, 'Sensor-173': 0.2052, 'Sensor-174': 0.4795, 'Sensor-175': 0.2052, 'Sensor-176': 0.6852, 'Sensor-177': 0.2519, 'Sensor-178': 0.429, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 25.15, 'Sensor-182': 0.768, 'Sensor-183': 11.18, 'Sensor-184': 20.038, 'Sensor-185': 0.1411, 'S ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95a3'), 'Wafer': 'Wafer-1401', 'Sensor-1': 3038.57, 'Sensor-2': 2380.39, 'Sensor-3': 2205.5, 'Sensor-4': 1287.3538, 'Sensor-5': 2.3842, 'Sensor-6': 100.0, 'Sensor-7': 111.7644, 'Sensor-8': 0.1241, 'Sensor-9': 1.4855, 'Sensor-10': -0.0034, 'Sensor-11': -0.0103, 'Sensor-12': 0.9639, 'Sensor-13': 202.7426, 'Sensor-14': 0, 'Sensor-15': 10.7755, 'Sensor-16': 412.1746, 'Sensor-17': 10.4716, 'Sensor-18': 0.9749, 'Sensor-19': 192.271, 'Sensor-20': 12.5339, 'Sensor-21': 1.4151, 'Sensor-22': -6376.25, 'Sensor-23': 2300.0, 'Sensor-24': -3671.25, 'Sensor-25': 422.5, 'Sensor-26': 0.6268, 'Sensor-27': 0.7112, 'Sensor-28': 3.6572, 'Sensor-29': 72.8556, 'Sensor-30': 2.0222, 'Sensor-31': 0.1487, 'Sensor-32': 2.2481, 'Sensor-33': 83.8792, 'Sensor-34': 8.6024, 'Sensor-35': 50.4179, 'Sensor-36': 64.5517, 'Sensor-37': 49.5821, 'Sensor-38': 65.9525, 'Sensor-39': 86.8309, 'Sensor-40': 117.5064, 'Sensor-41': 79.8, 'Sensor-42': 2.243, 'Sensor-43': 70, 'Sensor-44': 365.5645, 'Sensor-45': 10.0159, 'Sensor-46': 142.0136, 'Sensor-47': 753.0071, 'Sensor-48': 1.3192, 'Sensor-49': 140.9073, 'Sensor-50': 1, 'Sensor-51': 648.4855, 'Sensor-52': 228.264, 'Sensor-53': 0, 'Sensor-54': 4.635, 'Sensor-55': 4.89, 'Sensor-56': 2876, 'Sensor-57': 0.9161, 'Sensor-58': 0.9478, 'Sensor-59': 4.4969, 'Sensor-60': -2.1264, 'Sensor-61': 367.3427, 'Sensor-62': 10.5905, 'Sensor-63': 119.8873, 'Sensor-64': 11.5146, 'Sensor-65': 22.1264, 'Sensor-66': 25.2418, 'Sensor-67': 727.7653, 'Sensor-68': 0.8984, 'Sensor-69': 149.7409, 'Sensor-70': 1, 'Sensor-71': 636.9709, 'Sensor-72': 91.4862, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.0146, 'Sensor-77': -0.0298, 'Sensor-78': -0.0119, 'Sensor-79': -0.003, 'Sensor-80': 0.0017, 'Sensor-81': -0.0081, 'Sensor-82': -0.0287, 'Sensor-83': -0.025, 'Sensor-84': 8.081, 'Sensor-85': 0.1272, 'Sensor-86': None, 'Sensor-87': 2.3198, 'Sensor-88': 0.9688, 'Sensor-89': 1814.3941, 'Sensor-90': 0.1953, 'Sensor-91': 8549.18, 'Sensor-92': 0.113, 'Sensor-93': 0.0008, 'Sensor-94': -0.0004, 'Sensor-95': -0.0002, 'Sensor-96': 0.0001, 'Sensor-97': 0.2222, 'Sensor-98': 0, 'Sensor-99': -0.4961, 'Sensor-100': 0.0167, 'Sensor-101': 0.0001, 'Sensor-102': -0.0002, 'Sensor-103': -0.0452, 'Sensor-104': -0.0124, 'Sensor-105': -0.0002, 'Sensor-106': -0.0008, 'Sensor-107': 0.0004, 'Sensor-108': -0.0575, 'Sensor-109': -0.0933, 'Sensor-110': None, 'Sensor-111': None, 'Sensor-112': None, 'Sensor-113': None, 'Sensor-114': 0.9701, 'Sensor-115': 0.0, 'Sensor-116': 634.0758, 'Sensor-117': 0.9899, 'Sensor-118': 58.316, 'Sensor-119': 0.5949, 'Sensor-120': 0.9794, 'Sensor-121': 6.352, 'Sensor-122': 15.71, 'Sensor-123': 4.149, 'Sensor-124': 15.77, 'Sensor-125': 15.73, 'Sensor-126': 1.465, 'Sensor-127': 2.495, 'Sensor-128': 0.6866, 'Sensor-129': 3.106, 'Sensor-130': 0.0, 'Sensor-131': 0.6567, 'Sensor-132': 0.9961, 'Sensor-133': 2.3021, 'Sensor-134': 996.759, 'Sensor-135': 37.3925, 'Sensor-136': 124, 'Sensor-137': 83.8, 'Sensor-138': 137.0, 'Sensor-139': 56.5, 'Sensor-140': 411.964, 'Sensor-141': 0.5267, 'Sensor-142': 0.0, 'Sensor-143': 3.65, 'Sensor-144': 0.0049, 'Sensor-145': 0.1182, 'Sensor-146': 0.0893, 'Sensor-147': 0.0529, 'Sensor-148': 0.0199, 'Sensor-149': 7.5994, 'Sensor-150': 0, 'Sensor-151': 6.933, 'Sensor-152': 9.511, 'Sensor-153': 0.3104, 'Sensor-154': 0.0141, 'Sensor-155': 7.3465, 'Sensor-156': 0.6, 'Sensor-157': 0.044, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 130, 'Sensor-161': 54, 'Sensor-162': 204, 'Sensor-163': 214, 'Sensor-164': 0.216, 'Sensor-165': 0.219, 'Sensor-166': 0.236, 'Sensor-167': 2.2, 'Sensor-168': 0.3, 'Sensor-169': 0.079, 'Sensor-170': 0.08, 'Sensor-171': 0.447, 'Sensor-172': 0.1694, 'Sensor-173': 0.2034, 'Sensor-174': 0.5823, 'Sensor-175': 0.2034, 'Sensor-176': 0.7299, 'Sensor-177': 0.2085, 'Sensor-178': 0.137, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 21.46, 'Sensor-182': 0.679, 'Sensor-183': 15.87, 'Sensor-184': 17.163, 'Sensor-185': 0.2514, 'Sensor-186': 7.13, 'Sensor ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95a4'), 'Wafer': 'Wafer-1402', 'Sensor-1': 2902.88, 'Sensor-2': 2259.49, 'Sensor-3': 2205.5, 'Sensor-4': 1287.3538, 'Sensor-5': 2.3842, 'Sensor-6': 100.0, 'Sensor-7': 111.7644, 'Sensor-8': 0.1241, 'Sensor-9': 1.4089, 'Sensor-10': 0.0156, 'Sensor-11': -0.0142, 'Sensor-12': 0.9688, 'Sensor-13': 200.3339, 'Sensor-14': 0, 'Sensor-15': 7.6398, 'Sensor-16': 412.8915, 'Sensor-17': 9.7944, 'Sensor-18': 0.9715, 'Sensor-19': 190.5395, 'Sensor-20': 12.5214, 'Sensor-21': 1.3614, 'Sensor-22': -5337.25, 'Sensor-23': 2589.5, 'Sensor-24': -3612.5, 'Sensor-25': -3133.25, 'Sensor-26': 1.3427, 'Sensor-27': 1.989, 'Sensor-28': 7.4097, 'Sensor-29': 68.2667, 'Sensor-30': 2.3444, 'Sensor-31': 0.1846, 'Sensor-32': 3.4687, 'Sensor-33': 84.8142, 'Sensor-34': 9.9095, 'Sensor-35': 50.9039, 'Sensor-36': 64.2404, 'Sensor-37': 49.0961, 'Sensor-38': 66.1883, 'Sensor-39': 86.5141, 'Sensor-40': 120.267, 'Sensor-41': 81.76, 'Sensor-42': 2.663, 'Sensor-43': 70, 'Sensor-44': 373.1718, 'Sensor-45': 9.8194, 'Sensor-46': 144.1, 'Sensor-47': 762.8929, 'Sensor-48': 1.2544, 'Sensor-49': 137.6073, 'Sensor-50': 1, 'Sensor-51': 654.8791, 'Sensor-52': 215.4088, 'Sensor-53': 0, 'Sensor-54': 4.636, 'Sensor-55': 4.893, 'Sensor-56': 2869, 'Sensor-57': 0.9175, 'Sensor-58': 0.9474, 'Sensor-59': 4.4923, 'Sensor-60': -5.7373, 'Sensor-61': 372.4636, 'Sensor-62': 10.3959, 'Sensor-63': 118.3627, 'Sensor-64': 17.0755, 'Sensor-65': 25.7373, 'Sensor-66': 34.4785, 'Sensor-67': 728.4144, 'Sensor-68': 0.9335, 'Sensor-69': 146.9773, 'Sensor-70': 1, 'Sensor-71': 637.8036, 'Sensor-72': 101.619, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.0167, 'Sensor-77': -0.0026, 'Sensor-78': -0.0355, 'Sensor-79': -0.0011, 'Sensor-80': 0.0103, 'Sensor-81': -0.0054, 'Sensor-82': -0.0077, 'Sensor-83': -0.0331, 'Sensor-84': 8.3073, 'Sensor-85': 0.1302, 'Sensor-86': None, 'Sensor-87': 2.41, 'Sensor-88': 0.9724, 'Sensor-89': 1804.1424, 'Sensor-90': 0.1844, 'Sensor-91': 9156.08, 'Sensor-92': 0.1281, 'Sensor-93': 0.0016, 'Sensor-94': -0.0006, 'Sensor-95': 0.0001, 'Sensor-96': 0.0, 'Sensor-97': -0.1997, 'Sensor-98': 0, 'Sensor-99': 0.3468, 'Sensor-100': 0.0288, 'Sensor-101': 0.0001, 'Sensor-102': 0.0002, 'Sensor-103': -0.0323, 'Sensor-104': -0.0114, 'Sensor-105': -0.0004, 'Sensor-106': -0.0016, 'Sensor-107': 0.0006, 'Sensor-108': -0.0277, 'Sensor-109': -0.0224, 'Sensor-110': 0.9811, 'Sensor-111': 101.9651, 'Sensor-112': 230.3728, 'Sensor-113': None, 'Sensor-114': 0.9444, 'Sensor-115': 0.0, 'Sensor-116': 802.2167, 'Sensor-117': 0.99, 'Sensor-118': 58.4412, 'Sensor-119': 0.6037, 'Sensor-120': 0.9669, 'Sensor-121': 6.3423, 'Sensor-122': 15.7, 'Sensor-123': 4.04, 'Sensor-124': 15.73, 'Sensor-125': 15.71, 'Sensor-126': 1.276, 'Sensor-127': 2.533, 'Sensor-128': 0.6481, 'Sensor-129': 3.061, 'Sensor-130': 0.0, 'Sensor-131': 0.7048, 'Sensor-132': 0.9975, 'Sensor-133': 2.2959, 'Sensor-134': 993.8988, 'Sensor-135': 36.9265, 'Sensor-136': 110, 'Sensor-137': 72.6, 'Sensor-138': 42.2, 'Sensor-139': 56.5, 'Sensor-140': 411.964, 'Sensor-141': 0.5267, 'Sensor-142': 0.0, 'Sensor-143': 3.65, 'Sensor-144': 0.0049, 'Sensor-145': 0.1205, 'Sensor-146': 0.0689, 'Sensor-147': 0.0539, 'Sensor-148': 0.0158, 'Sensor-149': 8.3106, 'Sensor-150': 0, 'Sensor-151': 4.151, 'Sensor-152': 10.709, 'Sensor-153': 0.3424, 'Sensor-154': 0.0136, 'Sensor-155': 7.9862, 'Sensor-156': 0.2, 'Sensor-157': 0.0804, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 721, 'Sensor-161': 559, 'Sensor-162': 2305, 'Sensor-163': 10139, 'Sensor-164': 0.153, 'Sensor-165': 0.118, 'Sensor-166': 0.388, 'Sensor-167': 2.2, 'Sensor-168': 1.3, 'Sensor-169': 0.165, 'Sensor-170': 0.639, 'Sensor-171': 0.2979, 'Sensor-172': 0.2102, 'Sensor-173': 0.3466, 'Sensor-174': 0.6142, 'Sensor-175': 0.3466, 'Sensor-176': 0.6263, 'Sensor-177': 0.2526, 'Sensor-178': 0.202, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 21.75, 'Sensor-182': 0.55, 'Sensor-183': 13.19, 'Sensor-184': 18.968, 'Sensor-185': 0.2151, 'Sensor-186': 9.53 ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95a5'), 'Wafer': 'Wafer-1403', 'Sensor-1': 3001.45, 'Sensor-2': 2481.72, 'Sensor-3': 2162.5556, 'Sensor-4': 1041.0369, 'Sensor-5': 1.4305, 'Sensor-6': 100.0, 'Sensor-7': 100.4111, 'Sensor-8': 0.1238, 'Sensor-9': 1.6217, 'Sensor-10': -0.0088, 'Sensor-11': 0.0064, 'Sensor-12': 0.9635, 'Sensor-13': 201.9292, 'Sensor-14': 0, 'Sensor-15': 8.666, 'Sensor-16': 417.5414, 'Sensor-17': 9.3732, 'Sensor-18': 0.9696, 'Sensor-19': 192.556, 'Sensor-20': 12.452, 'Sensor-21': 1.4334, 'Sensor-22': -6517.75, 'Sensor-23': 2304.25, 'Sensor-24': -3732.25, 'Sensor-25': -211.0, 'Sensor-26': 1.074, 'Sensor-27': 1.8057, 'Sensor-28': 5.155, 'Sensor-29': 72.9778, 'Sensor-30': 1.4667, 'Sensor-31': 0.1081, 'Sensor-32': 4.6909, 'Sensor-33': 85.1237, 'Sensor-34': 8.1605, 'Sensor-35': 51.2093, 'Sensor-36': 64.415, 'Sensor-37': 48.7907, 'Sensor-38': 66.3805, 'Sensor-39': 86.629, 'Sensor-40': 117.9254, 'Sensor-41': 84.56, 'Sensor-42': 2.759, 'Sensor-43': 70, 'Sensor-44': 343.0455, 'Sensor-45': 10.1641, 'Sensor-46': 143.7882, 'Sensor-47': 730.8662, 'Sensor-48': 0.9116, 'Sensor-49': 138.8645, 'Sensor-50': 1, 'Sensor-51': 625.6982, 'Sensor-52': 138.8918, 'Sensor-53': 0, 'Sensor-54': 4.605, 'Sensor-55': 4.834, 'Sensor-56': 2803, 'Sensor-57': 0.9332, 'Sensor-58': 0.9525, 'Sensor-59': 4.5655, 'Sensor-60': 0.2055, 'Sensor-61': 346.2909, 'Sensor-62': 10.2887, 'Sensor-63': 123.9936, 'Sensor-64': 7.1904, 'Sensor-65': 19.7945, 'Sensor-66': 23.4023, 'Sensor-67': 707.4639, 'Sensor-68': 0.9216, 'Sensor-69': 150.3445, 'Sensor-70': 1, 'Sensor-71': 620.6291, 'Sensor-72': 109.115, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.014, 'Sensor-77': -0.0683, 'Sensor-78': 0.0058, 'Sensor-79': -0.0477, 'Sensor-80': -0.0108, 'Sensor-81': -0.0053, 'Sensor-82': -0.0232, 'Sensor-83': -0.0516, 'Sensor-84': 7.5433, 'Sensor-85': 0.1276, 'Sensor-86': 0.1136, 'Sensor-87': 2.4417, 'Sensor-88': 0.9876, 'Sensor-89': 1854.0569, 'Sensor-90': None, 'Sensor-91': None, 'Sensor-92': -0.1358, 'Sensor-93': 0.0011, 'Sensor-94': 0.0004, 'Sensor-95': -0.0001, 'Sensor-96': 0.0001, 'Sensor-97': 0.041, 'Sensor-98': 0, 'Sensor-99': -0.0195, 'Sensor-100': 0.0614, 'Sensor-101': -0.0001, 'Sensor-102': 0.0, 'Sensor-103': 0.0384, 'Sensor-104': -0.0101, 'Sensor-105': -0.0008, 'Sensor-106': -0.0011, 'Sensor-107': -0.0004, 'Sensor-108': -0.0078, 'Sensor-109': 0.0773, 'Sensor-110': 0.983, 'Sensor-111': 102.6452, 'Sensor-112': 235.1778, 'Sensor-113': None, 'Sensor-114': 0.9526, 'Sensor-115': 0.0, 'Sensor-116': 793.6932, 'Sensor-117': 0.9895, 'Sensor-118': 58.3055, 'Sensor-119': 0.6073, 'Sensor-120': 0.9688, 'Sensor-121': 6.3344, 'Sensor-122': 15.67, 'Sensor-123': 3.86, 'Sensor-124': 15.73, 'Sensor-125': 15.68, 'Sensor-126': 1.399, 'Sensor-127': 2.606, 'Sensor-128': 0.6872, 'Sensor-129': 3.092, 'Sensor-130': 0.2365, 'Sensor-131': 0.7422, 'Sensor-132': 0.996, 'Sensor-133': 2.2999, 'Sensor-134': 992.6206, 'Sensor-135': 37.2647, 'Sensor-136': 122, 'Sensor-137': 193.3, 'Sensor-138': 169.2, 'Sensor-139': 62.9001, 'Sensor-140': 142.106, 'Sensor-141': 0.1343, 'Sensor-142': 0.0, 'Sensor-143': 3.96, 'Sensor-144': 0.004, 'Sensor-145': 0.2595, 'Sensor-146': 0.0609, 'Sensor-147': 0.062, 'Sensor-148': 0.024, 'Sensor-149': 9.9915, 'Sensor-150': 0, 'Sensor-151': 3.258, 'Sensor-152': 12.861, 'Sensor-153': 0.5729, 'Sensor-154': 0.015, 'Sensor-155': 9.4853, 'Sensor-156': 0.18, 'Sensor-157': 0.0394, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 441, 'Sensor-161': 142, 'Sensor-162': 497, 'Sensor-163': 323, 'Sensor-164': 0.057, 'Sensor-165': 0.042, 'Sensor-166': 0.429, 'Sensor-167': 1.7, 'Sensor-168': 0.5, 'Sensor-169': 0.055, 'Sensor-170': 0.158, 'Sensor-171': 0.781, 'Sensor-172': 0.2361, 'Sensor-173': 0.2893, 'Sensor-174': 0.5125, 'Sensor-175': 0.2893, 'Sensor-176': 0.9272, 'Sensor-177': 0.3262, 'Sensor-178': 0.103, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 13.67, 'Sensor-182': 0.38, 'Sensor-183': 15.12, 'Sensor-184': 29.454, 'Sensor-185': 0.1359, 'Sensor-186': 11.7 ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95a6'), 'Wafer': 'Wafer-1404', 'Sensor-1': 2975.72, 'Sensor-2': 2585.72, 'Sensor-3': 2150.0556, 'Sensor-4': 1215.2183, 'Sensor-5': 1.4756, 'Sensor-6': 100.0, 'Sensor-7': 100.9744, 'Sensor-8': 0.1244, 'Sensor-9': 1.4413, 'Sensor-10': 0.0086, 'Sensor-11': -0.0173, 'Sensor-12': 0.9571, 'Sensor-13': 204.3916, 'Sensor-14': 0, 'Sensor-15': 13.7905, 'Sensor-16': 412.2705, 'Sensor-17': 9.8991, 'Sensor-18': 0.9666, 'Sensor-19': 194.4925, 'Sensor-20': 12.5214, 'Sensor-21': 1.4001, 'Sensor-22': -5552.25, 'Sensor-23': 2748.25, 'Sensor-24': -3828.3333, 'Sensor-25': -2236.6667, 'Sensor-26': 1.299, 'Sensor-27': 1.9762, 'Sensor-28': 7.324, 'Sensor-29': 74.2889, 'Sensor-30': 1.6333, 'Sensor-31': 0.1153, 'Sensor-32': 3.3791, 'Sensor-33': 85.07, 'Sensor-34': 8.3845, 'Sensor-35': 50.3494, 'Sensor-36': 64.3667, 'Sensor-37': 49.6506, 'Sensor-38': 65.9729, 'Sensor-39': 86.8972, 'Sensor-40': 117.5286, 'Sensor-41': 81.39, 'Sensor-42': 2.501, 'Sensor-43': 70, 'Sensor-44': 368.7091, 'Sensor-45': 9.9821, 'Sensor-46': 143.2073, 'Sensor-47': 758.7537, 'Sensor-48': 1.3072, 'Sensor-49': 142.0636, 'Sensor-50': 1, 'Sensor-51': 653.98, 'Sensor-52': 240.9286, 'Sensor-53': 0, 'Sensor-54': 4.648, 'Sensor-55': 4.889, 'Sensor-56': 2873, 'Sensor-57': 0.918, 'Sensor-58': 0.9506, 'Sensor-59': 4.5015, 'Sensor-60': -2.8245, 'Sensor-61': 367.7045, 'Sensor-62': 10.5732, 'Sensor-63': 120.3827, 'Sensor-64': 20.7773, 'Sensor-65': 22.8245, 'Sensor-66': 31.3699, 'Sensor-67': 727.3838, 'Sensor-68': 0.8979, 'Sensor-69': 145.1155, 'Sensor-70': 1, 'Sensor-71': 633.2027, 'Sensor-72': 125.3191, 'Sensor-73': 169.5949, 'Sensor-74': 463.6078, 'Sensor-75': 0.0, 'Sensor-76': 0.0368, 'Sensor-77': -0.0534, 'Sensor-78': -0.0234, 'Sensor-79': -0.0013, 'Sensor-80': -0.0116, 'Sensor-81': -0.0058, 'Sensor-82': -0.0064, 'Sensor-83': 0.0255, 'Sensor-84': 7.7935, 'Sensor-85': 0.1353, 'Sensor-86': None, 'Sensor-87': 2.4278, 'Sensor-88': 0.9863, 'Sensor-89': 1765.303, 'Sensor-90': 0.179, 'Sensor-91': 8442.0198, 'Sensor-92': -0.0574, 'Sensor-93': 0.0048, 'Sensor-94': -0.0031, 'Sensor-95': -0.0001, 'Sensor-96': 0.0, 'Sensor-97': 0.1852, 'Sensor-98': 0, 'Sensor-99': -0.2924, 'Sensor-100': -0.0353, 'Sensor-101': -0.0001, 'Sensor-102': -0.0001, 'Sensor-103': 0.0178, 'Sensor-104': -0.0117, 'Sensor-105': 0.0005, 'Sensor-106': -0.0048, 'Sensor-107': 0.0031, 'Sensor-108': -0.0679, 'Sensor-109': -0.0215, 'Sensor-110': 0.9809, 'Sensor-111': 102.2966, 'Sensor-112': 230.3673, 'Sensor-113': None, 'Sensor-114': 0.9443, 'Sensor-115': 0.0, 'Sensor-116': 719.0809, 'Sensor-117': 0.9896, 'Sensor-118': 60.1442, 'Sensor-119': 0.5975, 'Sensor-120': 0.9799, 'Sensor-121': 6.289, 'Sensor-122': 15.63, 'Sensor-123': 4.431, 'Sensor-124': 15.68, 'Sensor-125': 15.67, 'Sensor-126': 1.087, 'Sensor-127': 3.131, 'Sensor-128': 0.7335, 'Sensor-129': 3.339, 'Sensor-130': -1.797, 'Sensor-131': 0.7348, 'Sensor-132': 0.9964, 'Sensor-133': 2.2908, 'Sensor-134': 995.6526, 'Sensor-135': 39.4549, 'Sensor-136': 96, 'Sensor-137': 109.8, 'Sensor-138': 63.2, 'Sensor-139': 66.5999, 'Sensor-140': 286.615, 'Sensor-141': 0.3433, 'Sensor-142': 0.0, 'Sensor-143': 4.93, 'Sensor-144': 0.0049, 'Sensor-145': 0.1077, 'Sensor-146': 0.0699, 'Sensor-147': 0.048, 'Sensor-148': 0.0227, 'Sensor-149': 8.9784, 'Sensor-150': 0, 'Sensor-151': 7.787, 'Sensor-152': 6.532, 'Sensor-153': 0.7999, 'Sensor-154': 0.0167, 'Sensor-155': 8.3036, 'Sensor-156': 0.2, 'Sensor-157': 0.0451, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 708, 'Sensor-161': 398, 'Sensor-162': 1021, 'Sensor-163': 13898, 'Sensor-164': 0.145, 'Sensor-165': 0.127, 'Sensor-166': 0.443, 'Sensor-167': 2.3, 'Sensor-168': 1.0, 'Sensor-169': 0.1, 'Sensor-170': 0.534, 'Sensor-171': 0.5774, 'Sensor-172': 0.1081, 'Sensor-173': 0.2247, 'Sensor-174': 0.5877, 'Sensor-175': 0.2247, 'Sensor-176': 0.6512, 'Sensor-177': 0.34, 'Sensor-178': 0.326, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 23.08, 'Sensor-182': 0.679, 'Sensor-183': 12.24, 'Sensor-184': 16.639, 'Sensor-185': 0 ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95a7'), 'Wafer': 'Wafer-1405', 'Sensor-1': 3356.35, 'Sensor-2': 2815.31, 'Sensor-3': 2217.0, 'Sensor-4': 1436.8313, 'Sensor-5': 1.6604, 'Sensor-6': 100.0, 'Sensor-7': 93.6611, 'Sensor-8': 0.1199, 'Sensor-9': 1.5547, 'Sensor-10': -0.0048, 'Sensor-11': 0.002, 'Sensor-12': 0.962, 'Sensor-13': 196.3053, 'Sensor-14': 0, 'Sensor-15': 13.3154, 'Sensor-16': 427.8671, 'Sensor-17': 9.7313, 'Sensor-18': 0.9691, 'Sensor-19': 186.574, 'Sensor-20': 12.2937, 'Sensor-21': 1.4064, 'Sensor-22': -5731.5, 'Sensor-23': 2600.75, 'Sensor-24': -6240.5, 'Sensor-25': -312.75, 'Sensor-26': 1.284, 'Sensor-27': 1.9988, 'Sensor-28': 7.326, 'Sensor-29': 67.4333, 'Sensor-30': 2.8111, 'Sensor-31': 0.2312, 'Sensor-32': 3.2101, 'Sensor-33': 85.8796, 'Sensor-34': 8.7441, 'Sensor-35': 50.555, 'Sensor-36': 63.8465, 'Sensor-37': 49.445, 'Sensor-38': 66.1072, 'Sensor-39': 86.2696, 'Sensor-40': 118.6846, 'Sensor-41': 80.67, 'Sensor-42': 2.81, 'Sensor-43': 70, 'Sensor-44': 364.8836, 'Sensor-45': 9.9348, 'Sensor-46': 143.9818, 'Sensor-47': 752.0459, 'Sensor-48': 0.972, 'Sensor-49': 132.04, 'Sensor-50': 1, 'Sensor-51': 640.9055, 'Sensor-52': 76.2535, 'Sensor-53': 0, 'Sensor-54': 4.556, 'Sensor-55': 4.79, 'Sensor-56': 2888, 'Sensor-57': 0.9168, 'Sensor-58': 0.9512, 'Sensor-59': 4.5074, 'Sensor-60': -4.9336, 'Sensor-61': 363.9518, 'Sensor-62': 10.6086, 'Sensor-63': 119.0482, 'Sensor-64': 13.4246, 'Sensor-65': 24.9336, 'Sensor-66': 30.9695, 'Sensor-67': 721.0764, 'Sensor-68': 0.9101, 'Sensor-69': 144.4809, 'Sensor-70': 1, 'Sensor-71': 627.4809, 'Sensor-72': 83.5375, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': 0.0015, 'Sensor-77': -0.0541, 'Sensor-78': -0.0272, 'Sensor-79': 0.0295, 'Sensor-80': 0.0101, 'Sensor-81': -0.002, 'Sensor-82': -0.067, 'Sensor-83': 0.0466, 'Sensor-84': 7.2892, 'Sensor-85': 0.1318, 'Sensor-86': 0.1149, 'Sensor-87': 2.3999, 'Sensor-88': 0.9743, 'Sensor-89': 1798.5367, 'Sensor-90': 0.1766, 'Sensor-91': 9734.09, 'Sensor-92': -0.0189, 'Sensor-93': 0.0019, 'Sensor-94': -0.0003, 'Sensor-95': 0.0, 'Sensor-96': 0.0001, 'Sensor-97': -0.0451, 'Sensor-98': 0, 'Sensor-99': 0.0014, 'Sensor-100': -0.0595, 'Sensor-101': 0.0001, 'Sensor-102': 0.0, 'Sensor-103': -0.0104, 'Sensor-104': -0.0081, 'Sensor-105': 0.0008, 'Sensor-106': -0.0019, 'Sensor-107': 0.0003, 'Sensor-108': -0.0401, 'Sensor-109': -0.0423, 'Sensor-110': 0.9834, 'Sensor-111': 101.5483, 'Sensor-112': 235.4864, 'Sensor-113': None, 'Sensor-114': 0.9193, 'Sensor-115': 0.0, 'Sensor-116': 854.0502, 'Sensor-117': 0.99, 'Sensor-118': 58.5896, 'Sensor-119': 0.6002, 'Sensor-120': 0.9663, 'Sensor-121': 6.2292, 'Sensor-122': 15.64, 'Sensor-123': 4.173, 'Sensor-124': 15.68, 'Sensor-125': 15.57, 'Sensor-126': 1.097, 'Sensor-127': 2.625, 'Sensor-128': 0.6828, 'Sensor-129': 3.112, 'Sensor-130': 0.0, 'Sensor-131': 0.6722, 'Sensor-132': 0.9974, 'Sensor-133': 2.2799, 'Sensor-134': 993.1386, 'Sensor-135': 37.1686, 'Sensor-136': 125, 'Sensor-137': 157.9, 'Sensor-138': 102.9, 'Sensor-139': 51.0, 'Sensor-140': 504.072, 'Sensor-141': 0.2153, 'Sensor-142': 0.0, 'Sensor-143': 7.46, 'Sensor-144': 0.0042, 'Sensor-145': 0.21, 'Sensor-146': 0.0329, 'Sensor-147': 0.0586, 'Sensor-148': 0.0225, 'Sensor-149': 9.6854, 'Sensor-150': 0, 'Sensor-151': 11.096, 'Sensor-152': 8.854, 'Sensor-153': 0.516, 'Sensor-154': 0.0168, 'Sensor-155': 9.2457, 'Sensor-156': 0.27, 'Sensor-157': 0.0303, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 675, 'Sensor-161': 232, 'Sensor-162': 5819, 'Sensor-163': 1853, 'Sensor-164': 0.083, 'Sensor-165': 0.227, 'Sensor-166': 0.328, 'Sensor-167': 1.9, 'Sensor-168': 1.5, 'Sensor-169': 0.108, 'Sensor-170': 0.45, 'Sensor-171': 0.5201, 'Sensor-172': 0.051, 'Sensor-173': 0.2966, 'Sensor-174': 0.6308, 'Sensor-175': 0.2966, 'Sensor-176': 0.7712, 'Sensor-177': 0.2021, 'Sensor-178': 0.337, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 19.52, 'Sensor-182': 0.863, 'Sensor-183': 16.43, 'Sensor-184': 20.097, 'Sensor-185': 0.128, 'Sensor-186': 9.13, 'Sensor-187 ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95a8'), 'Wafer': 'Wafer-1406', 'Sensor-1': 3053.48, 'Sensor-2': 2524.95, 'Sensor-3': 2215.8111, 'Sensor-4': 1389.3065, 'Sensor-5': 2.3183, 'Sensor-6': 100.0, 'Sensor-7': 98.45, 'Sensor-8': 0.1214, 'Sensor-9': 1.5718, 'Sensor-10': 0.0211, 'Sensor-11': -0.0006, 'Sensor-12': 0.972, 'Sensor-13': 198.2412, 'Sensor-14': 0, 'Sensor-15': 10.2851, 'Sensor-16': 421.0322, 'Sensor-17': 9.7883, 'Sensor-18': 0.9761, 'Sensor-19': 188.4529, 'Sensor-20': 12.5718, 'Sensor-21': 1.4246, 'Sensor-22': -5313.5, 'Sensor-23': 2445.0, 'Sensor-24': -3865.5, 'Sensor-25': -4533.25, 'Sensor-26': 1.3142, 'Sensor-27': 1.9918, 'Sensor-28': 7.294, 'Sensor-29': 69.6556, 'Sensor-30': 2.2111, 'Sensor-31': 0.204, 'Sensor-32': 3.4446, 'Sensor-33': 84.7632, 'Sensor-34': 9.0402, 'Sensor-35': 50.6105, 'Sensor-36': 63.9938, 'Sensor-37': 49.3895, 'Sensor-38': 66.339, 'Sensor-39': 85.9998, 'Sensor-40': 119.6524, 'Sensor-41': 8.438, 'Sensor-42': 4.31, 'Sensor-43': 70, 'Sensor-44': 366.2827, 'Sensor-45': 10.0532, 'Sensor-46': 141.1827, 'Sensor-47': 753.228, 'Sensor-48': 1.3367, 'Sensor-49': 146.1618, 'Sensor-50': 1, 'Sensor-51': 653.6273, 'Sensor-52': 205.9865, 'Sensor-53': 0, 'Sensor-54': 4.638, 'Sensor-55': 4.893, 'Sensor-56': 2871, 'Sensor-57': 0.9223, 'Sensor-58': 0.9477, 'Sensor-59': 4.5444, 'Sensor-60': 3.1427, 'Sensor-61': 348.49, 'Sensor-62': 10.0862, 'Sensor-63': 124.3255, 'Sensor-64': 34.4209, 'Sensor-65': 16.8573, 'Sensor-66': 45.8089, 'Sensor-67': 707.4191, 'Sensor-68': 0.8263, 'Sensor-69': 146.3909, 'Sensor-70': 1, 'Sensor-71': 619.2064, 'Sensor-72': 107.8942, 'Sensor-73': 153.7026, 'Sensor-74': 465.5037, 'Sensor-75': 0.0, 'Sensor-76': 0.0123, 'Sensor-77': -0.0184, 'Sensor-78': -0.0485, 'Sensor-79': 0.0003, 'Sensor-80': -0.0198, 'Sensor-81': 0.0071, 'Sensor-82': -0.0118, 'Sensor-83': 0.0056, 'Sensor-84': 8.4695, 'Sensor-85': 0.1362, 'Sensor-86': None, 'Sensor-87': 2.488, 'Sensor-88': 0.9904, 'Sensor-89': 1760.9823, 'Sensor-90': 0.1823, 'Sensor-91': 8844.9701, 'Sensor-92': -0.183, 'Sensor-93': 0.0001, 'Sensor-94': 0.0007, 'Sensor-95': 0.0001, 'Sensor-96': 0.0, 'Sensor-97': -0.1279, 'Sensor-98': 0, 'Sensor-99': 0.213, 'Sensor-100': 0.0372, 'Sensor-101': 0.0001, 'Sensor-102': 0.0001, 'Sensor-103': 0.0898, 'Sensor-104': -0.0116, 'Sensor-105': -0.0005, 'Sensor-106': -0.0001, 'Sensor-107': -0.0007, 'Sensor-108': 0.013, 'Sensor-109': 0.0835, 'Sensor-110': 0.9825, 'Sensor-111': 99.1595, 'Sensor-112': 234.8522, 'Sensor-113': None, 'Sensor-114': 0.9607, 'Sensor-115': 0.0, 'Sensor-116': 766.6326, 'Sensor-117': 0.9898, 'Sensor-118': 58.3477, 'Sensor-119': 0.6022, 'Sensor-120': 0.9791, 'Sensor-121': 6.2864, 'Sensor-122': 15.73, 'Sensor-123': 3.853, 'Sensor-124': 15.78, 'Sensor-125': 15.77, 'Sensor-126': 1.163, 'Sensor-127': 2.723, 'Sensor-128': 0.6638, 'Sensor-129': 3.237, 'Sensor-130': -0.3311, 'Sensor-131': 0.7069, 'Sensor-132': 0.997, 'Sensor-133': 2.2539, 'Sensor-134': 997.4334, 'Sensor-135': 39.8795, 'Sensor-136': 88, 'Sensor-137': 219.5, 'Sensor-138': 193.7, 'Sensor-139': 53.3, 'Sensor-140': 565.522, 'Sensor-141': 0.6157, 'Sensor-142': 0.0, 'Sensor-143': 5.84, 'Sensor-144': 0.0035, 'Sensor-145': 0.3212, 'Sensor-146': 0.06, 'Sensor-147': 0.067, 'Sensor-148': 0.0126, 'Sensor-149': 11.7654, 'Sensor-150': 0, 'Sensor-151': 6.613, 'Sensor-152': 5.394, 'Sensor-153': 0.4457, 'Sensor-154': 0.0102, 'Sensor-155': 11.385, 'Sensor-156': 0.37, 'Sensor-157': 0.0673, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 1745, 'Sensor-161': 1057, 'Sensor-162': 2988, 'Sensor-163': 11768, 'Sensor-164': 0.221, 'Sensor-165': 0.059, 'Sensor-166': 0.165, 'Sensor-167': 3.0, 'Sensor-168': 1.2, 'Sensor-169': 0.138, 'Sensor-170': 0.688, 'Sensor-171': 0.5484, 'Sensor-172': 0.1324, 'Sensor-173': 0.3245, 'Sensor-174': 0.543, 'Sensor-175': 0.3245, 'Sensor-176': 0.6941, 'Sensor-177': 0.3403, 'Sensor-178': 0.166, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 18.9, 'Sensor-182': 0.382, 'Sensor-183': 12.48, 'Sensor-184': 17.779, 'Sensor-185': 0.2109, 'Sensor-186 ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95a9'), 'Wafer': 'Wafer-1407', 'Sensor-1': 2816.81, 'Sensor-2': 2557.2, 'Sensor-3': 2195.9778, 'Sensor-4': 1388.2869, 'Sensor-5': 1.5605, 'Sensor-6': 100.0, 'Sensor-7': 103.24, 'Sensor-8': 0.1234, 'Sensor-9': 1.4151, 'Sensor-10': 0.0213, 'Sensor-11': -0.0179, 'Sensor-12': 0.9566, 'Sensor-13': 195.8147, 'Sensor-14': 0, 'Sensor-15': 10.7529, 'Sensor-16': 406.3675, 'Sensor-17': 9.8672, 'Sensor-18': 0.9644, 'Sensor-19': 185.9476, 'Sensor-20': 12.4361, 'Sensor-21': 1.3943, 'Sensor-22': -5282.25, 'Sensor-23': 2557.0, 'Sensor-24': -4176.75, 'Sensor-25': -602.75, 'Sensor-26': 1.271, 'Sensor-27': 1.9925, 'Sensor-28': 7.2602, 'Sensor-29': 67.7778, 'Sensor-30': 2.8222, 'Sensor-31': 0.2273, 'Sensor-32': 3.4448, 'Sensor-33': 83.914, 'Sensor-34': 8.7286, 'Sensor-35': 50.8145, 'Sensor-36': 64.4394, 'Sensor-37': 49.1855, 'Sensor-38': 66.3143, 'Sensor-39': 86.3286, 'Sensor-40': 118.6336, 'Sensor-41': 80.23, 'Sensor-42': 3.005, 'Sensor-43': 70, 'Sensor-44': 367.2246, 'Sensor-45': 10.1884, 'Sensor-46': 126.7427, 'Sensor-47': 731.6706, 'Sensor-48': 0.9927, 'Sensor-49': 136.6645, 'Sensor-50': 1, 'Sensor-51': 630.6318, 'Sensor-52': 67.0449, 'Sensor-53': 0, 'Sensor-54': 4.627, 'Sensor-55': 4.849, 'Sensor-56': 2877, 'Sensor-57': 0.9228, 'Sensor-58': 0.954, 'Sensor-59': 4.5537, 'Sensor-60': 7.71, 'Sensor-61': 364.1545, 'Sensor-62': 10.6655, 'Sensor-63': 114.4527, 'Sensor-64': 4.8598, 'Sensor-65': 12.29, 'Sensor-66': 13.2099, 'Sensor-67': 718.4607, 'Sensor-68': 1.4518, 'Sensor-69': 148.0136, 'Sensor-70': 1, 'Sensor-71': 626.6209, 'Sensor-72': 146.7649, 'Sensor-73': 158.4378, 'Sensor-74': 468.1831, 'Sensor-75': 0.0, 'Sensor-76': -0.0095, 'Sensor-77': -0.0314, 'Sensor-78': -0.0201, 'Sensor-79': 0.0069, 'Sensor-80': 0.0025, 'Sensor-81': -0.0003, 'Sensor-82': -0.0109, 'Sensor-83': -0.0462, 'Sensor-84': 7.5539, 'Sensor-85': 0.1287, 'Sensor-86': None, 'Sensor-87': 2.4381, 'Sensor-88': 0.983, 'Sensor-89': 1880.0356, 'Sensor-90': 0.177, 'Sensor-91': 9379.6, 'Sensor-92': 0.2111, 'Sensor-93': 0.0005, 'Sensor-94': 0.0011, 'Sensor-95': 0.0001, 'Sensor-96': 0.0, 'Sensor-97': -0.0834, 'Sensor-98': 0, 'Sensor-99': 0.1551, 'Sensor-100': -0.0567, 'Sensor-101': 0.0, 'Sensor-102': 0.0001, 'Sensor-103': -0.0261, 'Sensor-104': -0.0114, 'Sensor-105': 0.0008, 'Sensor-106': -0.0005, 'Sensor-107': -0.0012, 'Sensor-108': 0.0176, 'Sensor-109': -0.015, 'Sensor-110': 0.9837, 'Sensor-111': 106.9227, 'Sensor-112': 231.2086, 'Sensor-113': None, 'Sensor-114': 0.9477, 'Sensor-115': 0.0, 'Sensor-116': 814.326, 'Sensor-117': 0.9901, 'Sensor-118': 58.6259, 'Sensor-119': 0.6034, 'Sensor-120': 0.9783, 'Sensor-121': 6.2251, 'Sensor-122': 15.73, 'Sensor-123': 4.138, 'Sensor-124': 15.77, 'Sensor-125': 15.73, 'Sensor-126': 1.13, 'Sensor-127': 2.673, 'Sensor-128': 0.6844, 'Sensor-129': 3.225, 'Sensor-130': -0.9461, 'Sensor-131': 0.7269, 'Sensor-132': 0.998, 'Sensor-133': 2.2711, 'Sensor-134': 997.5587, 'Sensor-135': 35.542, 'Sensor-136': 71, 'Sensor-137': 150.9, 'Sensor-138': 139.2, 'Sensor-139': 46.3999, 'Sensor-140': 888.49, 'Sensor-141': 0.2816, 'Sensor-142': 0.0, 'Sensor-143': 6.75, 'Sensor-144': 0.0033, 'Sensor-145': 0.1409, 'Sensor-146': 0.1253, 'Sensor-147': 0.1154, 'Sensor-148': 0.0265, 'Sensor-149': 12.7737, 'Sensor-150': 0, 'Sensor-151': 12.069, 'Sensor-152': 10.943, 'Sensor-153': 0.3758, 'Sensor-154': 0.0196, 'Sensor-155': 12.4652, 'Sensor-156': 0.41, 'Sensor-157': 0.0803, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 601, 'Sensor-161': 250, 'Sensor-162': 2056, 'Sensor-163': 2178, 'Sensor-164': 0.053, 'Sensor-165': 0.058, 'Sensor-166': 0.124, 'Sensor-167': 1.5, 'Sensor-168': 0.8, 'Sensor-169': 0.094, 'Sensor-170': 0.459, 'Sensor-171': 0.3728, 'Sensor-172': 0.1178, 'Sensor-173': 0.4271, 'Sensor-174': 0.555, 'Sensor-175': 0.4271, 'Sensor-176': 0.6667, 'Sensor-177': 0.18, 'Sensor-178': 0.299, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 21.25, 'Sensor-182': 0.982, 'Sensor-183': 15.88, 'Sensor-184': 17.022, 'Sensor-185': 0.1166, 'Sensor-186 ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95aa'), 'Wafer': 'Wafer-1408', 'Sensor-1': 3100.96, 'Sensor-2': 2507.02, 'Sensor-3': 2205.5, 'Sensor-4': 1287.3538, 'Sensor-5': 2.3842, 'Sensor-6': 100.0, 'Sensor-7': 111.7644, 'Sensor-8': 0.1241, 'Sensor-9': 1.5172, 'Sensor-10': 0.0074, 'Sensor-11': -0.0077, 'Sensor-12': 0.9661, 'Sensor-13': 202.6372, 'Sensor-14': 0, 'Sensor-15': 9.3697, 'Sensor-16': 419.9955, 'Sensor-17': 10.1518, 'Sensor-18': 0.9701, 'Sensor-19': 192.4855, 'Sensor-20': 12.5382, 'Sensor-21': 1.3898, 'Sensor-22': -5418.25, 'Sensor-23': 2663.75, 'Sensor-24': -4412.25, 'Sensor-25': -1841.25, 'Sensor-26': 1.3093, 'Sensor-27': 2.0275, 'Sensor-28': 7.3388, 'Sensor-29': 74.5889, 'Sensor-30': 2.1778, 'Sensor-31': 0.1582, 'Sensor-32': 3.2957, 'Sensor-33': 85.1167, 'Sensor-34': 8.2963, 'Sensor-35': 50.3384, 'Sensor-36': 64.3217, 'Sensor-37': 49.6616, 'Sensor-38': 66.0225, 'Sensor-39': 86.955, 'Sensor-40': 117.4422, 'Sensor-41': 80.59, 'Sensor-42': 3.53, 'Sensor-43': 70, 'Sensor-44': 371.3309, 'Sensor-45': 9.7565, 'Sensor-46': 139.1745, 'Sensor-47': 751.3179, 'Sensor-48': 0.9659, 'Sensor-49': 135.5827, 'Sensor-50': 1, 'Sensor-51': 646.0882, 'Sensor-52': 68.3778, 'Sensor-53': 0, 'Sensor-54': 4.636, 'Sensor-55': 4.893, 'Sensor-56': 2869, 'Sensor-57': 0.9175, 'Sensor-58': 0.9474, 'Sensor-59': 4.4923, 'Sensor-60': -3.1827, 'Sensor-61': 367.9182, 'Sensor-62': 10.5932, 'Sensor-63': 115.9918, 'Sensor-64': 13.9918, 'Sensor-65': 23.1827, 'Sensor-66': 29.8057, 'Sensor-67': 721.5122, 'Sensor-68': 0.9965, 'Sensor-69': 148.1864, 'Sensor-70': 1, 'Sensor-71': 632.0964, 'Sensor-72': 105.0281, 'Sensor-73': 167.5995, 'Sensor-74': 464.4968, 'Sensor-75': 0.0, 'Sensor-76': -0.0149, 'Sensor-77': -0.0262, 'Sensor-78': -0.0309, 'Sensor-79': -0.044, 'Sensor-80': 0.0135, 'Sensor-81': 0.0246, 'Sensor-82': -0.0167, 'Sensor-83': -0.0261, 'Sensor-84': 7.1634, 'Sensor-85': 0.1371, 'Sensor-86': None, 'Sensor-87': 2.367, 'Sensor-88': 0.9906, 'Sensor-89': 1834.1129, 'Sensor-90': 0.1784, 'Sensor-91': 8825.4601, 'Sensor-92': -0.2671, 'Sensor-93': -0.0026, 'Sensor-94': 0.0015, 'Sensor-95': -0.0002, 'Sensor-96': 0.0002, 'Sensor-97': 0.1716, 'Sensor-98': 0, 'Sensor-99': -0.2343, 'Sensor-100': 0.0939, 'Sensor-101': -0.0002, 'Sensor-102': -0.0001, 'Sensor-103': 0.0775, 'Sensor-104': -0.0096, 'Sensor-105': -0.0013, 'Sensor-106': 0.0026, 'Sensor-107': -0.0015, 'Sensor-108': 0.1073, 'Sensor-109': 0.1091, 'Sensor-110': 0.9829, 'Sensor-111': 100.4778, 'Sensor-112': 233.4095, 'Sensor-113': None, 'Sensor-114': 0.9509, 'Sensor-115': 0.0, 'Sensor-116': 755.2512, 'Sensor-117': 0.9889, 'Sensor-118': 61.1788, 'Sensor-119': 0.5947, 'Sensor-120': 0.9792, 'Sensor-121': 6.2196, 'Sensor-122': 15.71, 'Sensor-123': 4.149, 'Sensor-124': 15.77, 'Sensor-125': 15.73, 'Sensor-126': 1.465, 'Sensor-127': 2.495, 'Sensor-128': 0.6866, 'Sensor-129': 3.106, 'Sensor-130': 0.0, 'Sensor-131': 0.6567, 'Sensor-132': 0.9961, 'Sensor-133': 2.3021, 'Sensor-134': 996.759, 'Sensor-135': 37.3925, 'Sensor-136': 76, 'Sensor-137': 203.0, 'Sensor-138': 161.6, 'Sensor-139': 56.5, 'Sensor-140': 411.964, 'Sensor-141': 0.5267, 'Sensor-142': 0.0, 'Sensor-143': 3.65, 'Sensor-144': 0.0049, 'Sensor-145': 0.314, 'Sensor-146': 0.0703, 'Sensor-147': 0.0441, 'Sensor-148': 0.0178, 'Sensor-149': 7.0501, 'Sensor-150': 0, 'Sensor-151': 5.939, 'Sensor-152': 10.783, 'Sensor-153': 0.3008, 'Sensor-154': 0.0149, 'Sensor-155': 6.7492, 'Sensor-156': 0.25, 'Sensor-157': 0.0649, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 1166, 'Sensor-161': 395, 'Sensor-162': 4579, 'Sensor-163': 1713, 'Sensor-164': 0.224, 'Sensor-165': 0.178, 'Sensor-166': 0.146, 'Sensor-167': 2.3, 'Sensor-168': 2.2, 'Sensor-169': 0.155, 'Sensor-170': 0.585, 'Sensor-171': 0.6925, 'Sensor-172': 0.047, 'Sensor-173': 0.2023, 'Sensor-174': 0.5372, 'Sensor-175': 0.2023, 'Sensor-176': 0.6042, 'Sensor-177': 0.2334, 'Sensor-178': 0.309, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 22.58, 'Sensor-182': 0.91, 'Sensor-183': 14.11, 'Sensor-184': 17.425, 'Sensor-185': 0.20 ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95ab'), 'Wafer': 'Wafer-1409', 'Sensor-1': 2951.84, 'Sensor-2': 2477.13, 'Sensor-3': 2192.1889, 'Sensor-4': 1435.9611, 'Sensor-5': 2.387, 'Sensor-6': 100.0, 'Sensor-7': 107.3989, 'Sensor-8': 0.1229, 'Sensor-9': 1.4613, 'Sensor-10': -0.0027, 'Sensor-11': -0.0039, 'Sensor-12': 0.978, 'Sensor-13': 199.9289, 'Sensor-14': 0, 'Sensor-15': 11.1558, 'Sensor-16': 412.4685, 'Sensor-17': 9.8161, 'Sensor-18': 0.9804, 'Sensor-19': 190.1128, 'Sensor-20': 12.6241, 'Sensor-21': 1.4189, 'Sensor-22': -6333.25, 'Sensor-23': 2278.5, 'Sensor-24': -3596.75, 'Sensor-25': 462.25, 'Sensor-26': 0.65, 'Sensor-27': 0.6785, 'Sensor-28': 3.6052, 'Sensor-29': 73.3778, 'Sensor-30': 1.8667, 'Sensor-31': 0.1436, 'Sensor-32': 2.2027, 'Sensor-33': 83.8792, 'Sensor-34': 8.6024, 'Sensor-35': 50.4179, 'Sensor-36': 64.5517, 'Sensor-37': 49.5821, 'Sensor-38': 65.9525, 'Sensor-39': 86.8309, 'Sensor-40': 117.5064, 'Sensor-41': 79.8, 'Sensor-42': 2.243, 'Sensor-43': 70, 'Sensor-44': 346.2527, 'Sensor-45': 10.0479, 'Sensor-46': 145.8382, 'Sensor-47': 737.5634, 'Sensor-48': 1.3035, 'Sensor-49': 140.4864, 'Sensor-50': 1, 'Sensor-51': 632.5773, 'Sensor-52': 207.3696, 'Sensor-53': 0, 'Sensor-54': 4.605, 'Sensor-55': 4.866, 'Sensor-56': 2820, 'Sensor-57': 0.9312, 'Sensor-58': 0.9463, 'Sensor-59': 4.5909, 'Sensor-60': -5.1645, 'Sensor-61': 350.4855, 'Sensor-62': 10.2117, 'Sensor-63': 120.6736, 'Sensor-64': 14.36, 'Sensor-65': 25.1645, 'Sensor-66': 32.5683, 'Sensor-67': 704.9951, 'Sensor-68': 0.844, 'Sensor-69': 147.0582, 'Sensor-70': 1, 'Sensor-71': 618.2173, 'Sensor-72': 104.6066, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.0076, 'Sensor-77': 0.0084, 'Sensor-78': -0.032, 'Sensor-79': 0.0283, 'Sensor-80': 0.0059, 'Sensor-81': -0.0072, 'Sensor-82': -0.0074, 'Sensor-83': 0.0036, 'Sensor-84': 7.9018, 'Sensor-85': 0.1347, 'Sensor-86': None, 'Sensor-87': 2.4146, 'Sensor-88': 0.9895, 'Sensor-89': 1955.8828, 'Sensor-90': 0.1718, 'Sensor-91': 8862.2601, 'Sensor-92': 0.1514, 'Sensor-93': 0.0005, 'Sensor-94': -0.0013, 'Sensor-95': -0.0001, 'Sensor-96': 0.0001, 'Sensor-97': 0.1616, 'Sensor-98': 0, 'Sensor-99': -0.3247, 'Sensor-100': 0.0298, 'Sensor-101': 0.0, 'Sensor-102': -0.0001, 'Sensor-103': -0.0237, 'Sensor-104': -0.0114, 'Sensor-105': -0.0004, 'Sensor-106': -0.0005, 'Sensor-107': 0.0013, 'Sensor-108': -0.0153, 'Sensor-109': -0.0001, 'Sensor-110': 0.9827, 'Sensor-111': 99.3219, 'Sensor-112': 234.0516, 'Sensor-113': None, 'Sensor-114': 0.9485, 'Sensor-115': 0.0, 'Sensor-116': 735.8611, 'Sensor-117': 0.99, 'Sensor-118': 58.3392, 'Sensor-119': 0.5992, 'Sensor-120': 0.98, 'Sensor-121': 6.1972, 'Sensor-122': 15.72, 'Sensor-123': 2.398, 'Sensor-124': 15.71, 'Sensor-125': 15.73, 'Sensor-126': 0.9365, 'Sensor-127': 2.985, 'Sensor-128': 0.4108, 'Sensor-129': 3.398, 'Sensor-130': 0.3784, 'Sensor-131': 0.8741, 'Sensor-132': 1.0, 'Sensor-133': 2.2732, 'Sensor-134': 1000.1451, 'Sensor-135': 37.0354, 'Sensor-136': 107, 'Sensor-137': 91.6, 'Sensor-138': 97.5, 'Sensor-139': 62.1001, 'Sensor-140': 324.222, 'Sensor-141': 0.6996, 'Sensor-142': 0.0, 'Sensor-143': 4.57, 'Sensor-144': 0.0031, 'Sensor-145': 0.0875, 'Sensor-146': 0.0597, 'Sensor-147': 0.0558, 'Sensor-148': 0.0075, 'Sensor-149': 7.6878, 'Sensor-150': 0, 'Sensor-151': 12.897, 'Sensor-152': 7.288, 'Sensor-153': 0.4527, 'Sensor-154': 0.0061, 'Sensor-155': 7.6293, 'Sensor-156': 0.26, 'Sensor-157': 0.0503, 'Sensor-158': 0.036, 'Sensor-159': 1294.7998, 'Sensor-160': 338, 'Sensor-161': 76, 'Sensor-162': 223, 'Sensor-163': 383, 'Sensor-164': 0.233, 'Sensor-165': 0.258, 'Sensor-166': 0.2, 'Sensor-167': 2.9, 'Sensor-168': 0.9, 'Sensor-169': 0.123, 'Sensor-170': 0.167, 'Sensor-171': 0.447, 'Sensor-172': 0.1694, 'Sensor-173': 0.2034, 'Sensor-174': 0.5823, 'Sensor-175': 0.2034, 'Sensor-176': 0.7299, 'Sensor-177': 0.2085, 'Sensor-178': 0.137, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 15.66, 'Sensor-182': 0.254, 'Sensor-183': 15.12, 'Sensor-184': 32.175, 'Sensor-185': 0.162, 'Sensor-1 ...
#
# {'_id': ObjectId('604103f31a89d5420c5e95ac'), 'Wafer': 'Wafer-1410', 'Sensor-1': 3004.07, 'Sensor-2': 2458.88, 'Sensor-3': 2180.8889, 'Sensor-4': 1084.7221, 'Sensor-5': 0.9085, 'Sensor-6': 100.0, 'Sensor-7': 94.2467, 'Sensor-8': 0.1226, 'Sensor-9': 1.2957, 'Sensor-10': 0.0186, 'Sensor-11': 0.007, 'Sensor-12': 0.9676, 'Sensor-13': 193.584, 'Sensor-14': 0, 'Sensor-15': 8.6656, 'Sensor-16': 413.1059, 'Sensor-17': 10.2127, 'Sensor-18': 0.9745, 'Sensor-19': 183.3713, 'Sensor-20': 12.5339, 'Sensor-21': 1.3829, 'Sensor-22': -5497.5, 'Sensor-23': 2578.0, 'Sensor-24': -4057.25, 'Sensor-25': -378.0, 'Sensor-26': 1.2688, 'Sensor-27': 1.9745, 'Sensor-28': 7.2538, 'Sensor-29': 72.1111, 'Sensor-30': 1.9333, 'Sensor-31': 0.1599, 'Sensor-32': 3.5178, 'Sensor-33': 85.2544, 'Sensor-34': 8.3675, 'Sensor-35': 50.2934, 'Sensor-36': 64.3032, 'Sensor-37': 49.7066, 'Sensor-38': 66.0584, 'Sensor-39': 86.8342, 'Sensor-40': 117.487, 'Sensor-41': 2.506, 'Sensor-42': 1.582, 'Sensor-43': 70, 'Sensor-44': 363.6127, 'Sensor-45': 10.0414, 'Sensor-46': 141.7373, 'Sensor-47': 750.4688, 'Sensor-48': 1.3041, 'Sensor-49': 141.1027, 'Sensor-50': 1, 'Sensor-51': 646.4527, 'Sensor-52': 196.5638, 'Sensor-53': 0, 'Sensor-54': 4.635, 'Sensor-55': 4.89, 'Sensor-56': 2876, 'Sensor-57': 0.9161, 'Sensor-58': 0.9478, 'Sensor-59': 4.4969, 'Sensor-60': -3.5064, 'Sensor-61': 364.34, 'Sensor-62': 10.5752, 'Sensor-63': 118.2309, 'Sensor-64': 15.7082, 'Sensor-65': 23.5064, 'Sensor-66': 29.7574, 'Sensor-67': 720.7115, 'Sensor-68': 0.9153, 'Sensor-69': 148.1736, 'Sensor-70': 1, 'Sensor-71': 630.7445, 'Sensor-72': 93.9988, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.0231, 'Sensor-77': -0.0211, 'Sensor-78': -0.0331, 'Sensor-79': -0.0026, 'Sensor-80': 0.0091, 'Sensor-81': 0.0149, 'Sensor-82': -0.0123, 'Sensor-83': -0.0298, 'Sensor-84': 6.9761, 'Sensor-85': 0.1339, 'Sensor-86': None, 'Sensor-87': 2.4392, 'Sensor-88': 0.9906, 'Sensor-89': 1862.0343, 'Sensor-90': None, 'Sensor-91': None, 'Sensor-92': -0.0009, 'Sensor-93': 0.001, 'Sensor-94': -0.0019, 'Sensor-95': -0.0001, 'Sensor-96': 0.0, 'Sensor-97': 0.124, 'Sensor-98': 0, 'Sensor-99': -0.123, 'Sensor-100': 0.013, 'Sensor-101': -0.0002, 'Sensor-102': -0.0001, 'Sensor-103': 0.0624, 'Sensor-104': -0.0119, 'Sensor-105': -0.0002, 'Sensor-106': -0.001, 'Sensor-107': 0.0019, 'Sensor-108': 0.0476, 'Sensor-109': 0.0876, 'Sensor-110': 0.9821, 'Sensor-111': 98.256, 'Sensor-112': 235.1122, 'Sensor-113': None, 'Sensor-114': 0.9409, 'Sensor-115': 0.0, 'Sensor-116': 852.6576, 'Sensor-117': 0.9895, 'Sensor-118': 59.3411, 'Sensor-119': 0.5992, 'Sensor-120': 0.9806, 'Sensor-121': 6.1307, 'Sensor-122': 15.71, 'Sensor-123': 4.149, 'Sensor-124': 15.77, 'Sensor-125': 15.73, 'Sensor-126': 1.465, 'Sensor-127': 2.495, 'Sensor-128': 0.6866, 'Sensor-129': 3.106, 'Sensor-130': 0.0, 'Sensor-131': 0.6567, 'Sensor-132': 0.9961, 'Sensor-133': 2.3021, 'Sensor-134': 996.759, 'Sensor-135': 37.3925, 'Sensor-136': 96, 'Sensor-137': 129.9, 'Sensor-138': 66.2, 'Sensor-139': 57.3999, 'Sensor-140': 1025.2109, 'Sensor-141': 0.1294, 'Sensor-142': 0.0, 'Sensor-143': 9.56, 'Sensor-144': 0.0035, 'Sensor-145': 0.0716, 'Sensor-146': 0.0784, 'Sensor-147': 0.0649, 'Sensor-148': 0.0167, 'Sensor-149': 12.2549, 'Sensor-150': 0, 'Sensor-151': 4.499, 'Sensor-152': 11.138, 'Sensor-153': 0.5634, 'Sensor-154': 0.0094, 'Sensor-155': 11.724, 'Sensor-156': 0.6, 'Sensor-157': 0.0714, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 439, 'Sensor-161': 642, 'Sensor-162': 1645, 'Sensor-163': 15651, 'Sensor-164': 0.123, 'Sensor-165': 0.143, 'Sensor-166': 0.104, 'Sensor-167': 1.9, 'Sensor-168': 1.4, 'Sensor-169': 0.123, 'Sensor-170': 0.151, 'Sensor-171': 0.5344, 'Sensor-172': 0.1325, 'Sensor-173': 0.2052, 'Sensor-174': 0.4795, 'Sensor-175': 0.2052, 'Sensor-176': 0.6852, 'Sensor-177': 0.2519, 'Sensor-178': 0.429, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 24.07, 'Sensor-182': 0.826, 'Sensor-183': 14.12, 'Sensor-184': 17.2141, 'Sensor-185': 0.2676, 'Sensor-186': 10. ...
#
# ...
#
# {'_id': ObjectId('604103f31a89d5420c5e9603'), 'Wafer': 'Wafer-1497', 'Sensor-1': 3042.45, 'Sensor-2': 2530.96, 'Sensor-3': 2191.3556, 'Sensor-4': 1111.4764, 'Sensor-5': 1.4549, 'Sensor-6': 100.0, 'Sensor-7': 97.1556, 'Sensor-8': 0.121, 'Sensor-9': 1.3345, 'Sensor-10': 0.0085, 'Sensor-11': 0.0097, 'Sensor-12': 0.9703, 'Sensor-13': 196.752, 'Sensor-14': 0, 'Sensor-15': 12.7776, 'Sensor-16': 413.289, 'Sensor-17': 10.3091, 'Sensor-18': 0.9755, 'Sensor-19': 186.4429, 'Sensor-20': 12.3869, 'Sensor-21': 1.4326, 'Sensor-22': -5587.0, 'Sensor-23': 2552.5, 'Sensor-24': -6854.5, 'Sensor-25': -2980.0, 'Sensor-26': 1.3335, 'Sensor-27': 2.0065, 'Sensor-28': 7.448, 'Sensor-29': 71.7, 'Sensor-30': 1.7556, 'Sensor-31': 0.1571, 'Sensor-32': 3.5019, 'Sensor-33': 86.7232, 'Sensor-34': 8.3271, 'Sensor-35': 50.6765, 'Sensor-36': 64.0969, 'Sensor-37': 49.3235, 'Sensor-38': 65.9364, 'Sensor-39': 87.0707, 'Sensor-40': 116.057, 'Sensor-41': 8.828, 'Sensor-42': 5.129, 'Sensor-43': 70, 'Sensor-44': 344.3245, 'Sensor-45': 10.1429, 'Sensor-46': 143.81, 'Sensor-47': 731.3436, 'Sensor-48': 0.9224, 'Sensor-49': 139.42, 'Sensor-50': 1, 'Sensor-51': 627.5545, 'Sensor-52': 142.8061, 'Sensor-53': 0, 'Sensor-54': 4.605, 'Sensor-55': 4.834, 'Sensor-56': 2803, 'Sensor-57': 0.9332, 'Sensor-58': 0.9525, 'Sensor-59': 4.5655, 'Sensor-60': -3.6509, 'Sensor-61': 348.3382, 'Sensor-62': 10.1326, 'Sensor-63': 120.1591, 'Sensor-64': 5.9923, 'Sensor-65': 23.6509, 'Sensor-66': 29.6804, 'Sensor-67': 701.6633, 'Sensor-68': 0.9813, 'Sensor-69': 155.1155, 'Sensor-70': 1, 'Sensor-71': 623.6127, 'Sensor-72': 102.0092, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.0156, 'Sensor-77': -0.0001, 'Sensor-78': -0.0454, 'Sensor-79': -0.0552, 'Sensor-80': 0.0013, 'Sensor-81': 0.0027, 'Sensor-82': -0.0142, 'Sensor-83': -0.0717, 'Sensor-84': 8.1309, 'Sensor-85': 0.1378, 'Sensor-86': None, 'Sensor-87': 2.4329, 'Sensor-88': 0.9901, 'Sensor-89': 1800.3704, 'Sensor-90': 0.1635, 'Sensor-91': 8709.7301, 'Sensor-92': 0.1122, 'Sensor-93': -0.0009, 'Sensor-94': -0.0023, 'Sensor-95': 0.0001, 'Sensor-96': 0.0, 'Sensor-97': -0.1326, 'Sensor-98': 0, 'Sensor-99': 0.4434, 'Sensor-100': 0.067, 'Sensor-101': -0.0003, 'Sensor-102': 0.0002, 'Sensor-103': -0.0458, 'Sensor-104': -0.0125, 'Sensor-105': -0.0009, 'Sensor-106': 0.0009, 'Sensor-107': 0.0023, 'Sensor-108': 0.0361, 'Sensor-109': -0.0463, 'Sensor-110': 0.9799, 'Sensor-111': 102.1809, 'Sensor-112': 229.5486, 'Sensor-113': None, 'Sensor-114': 0.9572, 'Sensor-115': 0.0, 'Sensor-116': 756.0542, 'Sensor-117': 0.9894, 'Sensor-118': 59.6947, 'Sensor-119': 0.5777, 'Sensor-120': 0.9648, 'Sensor-121': 6.4518, 'Sensor-122': 15.74, 'Sensor-123': 4.635, 'Sensor-124': 15.77, 'Sensor-125': 15.75, 'Sensor-126': 1.513, 'Sensor-127': 2.832, 'Sensor-128': 0.7813, 'Sensor-129': 3.325, 'Sensor-130': -1.088, 'Sensor-131': 0.4199, 'Sensor-132': 0.9979, 'Sensor-133': 2.2785, 'Sensor-134': 1011.88, 'Sensor-135': 64.1287, 'Sensor-136': 103, 'Sensor-137': 81.0, 'Sensor-138': 79.6, 'Sensor-139': 60.4001, 'Sensor-140': 329.892, 'Sensor-141': 0.2045, 'Sensor-142': 0.0, 'Sensor-143': 4.49, 'Sensor-144': 0.0044, 'Sensor-145': 0.1082, 'Sensor-146': 0.0522, 'Sensor-147': 0.0585, 'Sensor-148': 0.011, 'Sensor-149': 3.7667, 'Sensor-150': 0, 'Sensor-151': 12.321, 'Sensor-152': 5.996, 'Sensor-153': 0.1884, 'Sensor-154': 0.0086, 'Sensor-155': 3.7174, 'Sensor-156': 0.2, 'Sensor-157': 0.0861, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 739, 'Sensor-161': 427, 'Sensor-162': 18365, 'Sensor-163': 13617, 'Sensor-164': 0.076, 'Sensor-165': 0.154, 'Sensor-166': 0.345, 'Sensor-167': 1.7, 'Sensor-168': 0.7, 'Sensor-169': 0.109, 'Sensor-170': 0.713, 'Sensor-171': 0.7345, 'Sensor-172': 0.1843, 'Sensor-173': 0.4718, 'Sensor-174': 0.5273, 'Sensor-175': 0.4718, 'Sensor-176': 0.8375, 'Sensor-177': 0.1038, 'Sensor-178': 0.505, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 18.31, 'Sensor-182': 0.524, 'Sensor-183': 12.7, 'Sensor-184': 28.127, 'Sensor-185': 0.0731, 'Sensor-186' ...
#
# {'_id': ObjectId('604103f31a89d5420c5e9604'), 'Wafer': 'Wafer-1498', 'Sensor-1': 3051.2, 'Sensor-2': 2401.59, 'Sensor-3': 2190.7666, 'Sensor-4': 3530.2362, 'Sensor-5': 0.8017, 'Sensor-6': 100.0, 'Sensor-7': 83.8767, 'Sensor-8': 0.1249, 'Sensor-9': 1.3226, 'Sensor-10': 0.0025, 'Sensor-11': 0.0085, 'Sensor-12': 0.9778, 'Sensor-13': 198.5596, 'Sensor-14': 0, 'Sensor-15': 13.4235, 'Sensor-16': 422.4587, 'Sensor-17': 9.7023, 'Sensor-18': 0.9808, 'Sensor-19': 188.8572, 'Sensor-20': 12.479, 'Sensor-21': 1.3872, 'Sensor-22': -5566.0, 'Sensor-23': 2617.0, 'Sensor-24': -4173.25, 'Sensor-25': 94.0, 'Sensor-26': 1.294, 'Sensor-27': 2.0002, 'Sensor-28': 7.3335, 'Sensor-29': 74.3667, 'Sensor-30': 2.8333, 'Sensor-31': 0.2082, 'Sensor-32': 3.3894, 'Sensor-33': 84.1818, 'Sensor-34': 9.2189, 'Sensor-35': 50.1644, 'Sensor-36': 64.0575, 'Sensor-37': 49.8356, 'Sensor-38': 66.0288, 'Sensor-39': 86.6498, 'Sensor-40': 119.3766, 'Sensor-41': 77.7, 'Sensor-42': 3.051, 'Sensor-43': 70, 'Sensor-44': 362.4545, 'Sensor-45': 10.0436, 'Sensor-46': 143.9145, 'Sensor-47': 751.587, 'Sensor-48': 0.8728, 'Sensor-49': 136.1236, 'Sensor-50': 1, 'Sensor-51': 642.4927, 'Sensor-52': 141.2025, 'Sensor-53': 0, 'Sensor-54': 4.594, 'Sensor-55': 4.823, 'Sensor-56': 2874, 'Sensor-57': 0.9187, 'Sensor-58': 0.9524, 'Sensor-59': 4.5479, 'Sensor-60': -2.5382, 'Sensor-61': 364.6755, 'Sensor-62': 10.237, 'Sensor-63': 121.3764, 'Sensor-64': 6.8877, 'Sensor-65': 22.5382, 'Sensor-66': 29.1744, 'Sensor-67': 722.4126, 'Sensor-68': 0.9885, 'Sensor-69': 150.7482, 'Sensor-70': 1, 'Sensor-71': 636.8, 'Sensor-72': 124.5219, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.0174, 'Sensor-77': 0.0254, 'Sensor-78': -0.0336, 'Sensor-79': -0.0491, 'Sensor-80': 0.0147, 'Sensor-81': 0.0037, 'Sensor-82': -0.0223, 'Sensor-83': -0.0674, 'Sensor-84': 7.6743, 'Sensor-85': 0.1452, 'Sensor-86': 0.1147, 'Sensor-87': 2.3906, 'Sensor-88': 0.9758, 'Sensor-89': 1759.9908, 'Sensor-90': None, 'Sensor-91': None, 'Sensor-92': -0.0757, 'Sensor-93': 0.0003, 'Sensor-94': 0.0004, 'Sensor-95': 0.0, 'Sensor-96': 0.0001, 'Sensor-97': 0.0255, 'Sensor-98': 0, 'Sensor-99': 0.2302, 'Sensor-100': 0.0102, 'Sensor-101': -0.0004, 'Sensor-102': 0.0001, 'Sensor-103': -0.023, 'Sensor-104': -0.013, 'Sensor-105': -0.0001, 'Sensor-106': -0.0003, 'Sensor-107': -0.0004, 'Sensor-108': 0.0561, 'Sensor-109': 0.0659, 'Sensor-110': 0.9811, 'Sensor-111': 102.233, 'Sensor-112': 230.2986, 'Sensor-113': None, 'Sensor-114': 0.9385, 'Sensor-115': 0.0, 'Sensor-116': 681.8888, 'Sensor-117': 0.9894, 'Sensor-118': 58.4712, 'Sensor-119': 0.594, 'Sensor-120': 0.9685, 'Sensor-121': 6.1396, 'Sensor-122': 15.74, 'Sensor-123': 4.635, 'Sensor-124': 15.77, 'Sensor-125': 15.75, 'Sensor-126': 1.513, 'Sensor-127': 2.832, 'Sensor-128': 0.7813, 'Sensor-129': 3.325, 'Sensor-130': -1.088, 'Sensor-131': 0.4199, 'Sensor-132': 0.9979, 'Sensor-133': 2.2785, 'Sensor-134': 1011.88, 'Sensor-135': 64.1287, 'Sensor-136': 96, 'Sensor-137': 104.6, 'Sensor-138': 73.6, 'Sensor-139': 27.9001, 'Sensor-140': 1258.052, 'Sensor-141': 0.1014, 'Sensor-142': 0.0, 'Sensor-143': 7.96, 'Sensor-144': 0.0029, 'Sensor-145': 0.1419, 'Sensor-146': 0.0545, 'Sensor-147': 0.0671, 'Sensor-148': 0.0069, 'Sensor-149': 9.9167, 'Sensor-150': 0, 'Sensor-151': 7.586, 'Sensor-152': 6.212, 'Sensor-153': 0.5158, 'Sensor-154': 0.0054, 'Sensor-155': 9.4009, 'Sensor-156': 0.23, 'Sensor-157': 0.0907, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 967, 'Sensor-161': 536, 'Sensor-162': 3094, 'Sensor-163': 936, 'Sensor-164': 0.186, 'Sensor-165': 0.141, 'Sensor-166': 0.188, 'Sensor-167': 5.3, 'Sensor-168': 1.0, 'Sensor-169': 0.085, 'Sensor-170': 0.437, 'Sensor-171': 0.6269, 'Sensor-172': 0.2929, 'Sensor-173': 0.4214, 'Sensor-174': 0.5831, 'Sensor-175': 0.4214, 'Sensor-176': 0.7039, 'Sensor-177': 0.2744, 'Sensor-178': 0.339, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 23.33, 'Sensor-182': 0.832, 'Sensor-183': 14.05, 'Sensor-184': 20.912, 'Sensor-185': 0.1207, 'Sensor-186': 7.64, 'S ...
#
# {'_id': ObjectId('604103f31a89d5420c5e9605'), 'Wafer': 'Wafer-1499', 'Sensor-1': 3028.34, 'Sensor-2': 2499.72, 'Sensor-3': 2179.7333, 'Sensor-4': 3085.3781, 'Sensor-5': 1.4843, 'Sensor-6': 100.0, 'Sensor-7': 82.2467, 'Sensor-8': 0.1248, 'Sensor-9': 1.3307, 'Sensor-10': -0.0077, 'Sensor-11': 0.0046, 'Sensor-12': 0.9594, 'Sensor-13': 197.2747, 'Sensor-14': 0, 'Sensor-15': 8.852, 'Sensor-16': 414.6622, 'Sensor-17': 10.2507, 'Sensor-18': 0.9698, 'Sensor-19': 187.024, 'Sensor-20': 12.3937, 'Sensor-21': 1.4058, 'Sensor-22': -5337.0, 'Sensor-23': 2561.25, 'Sensor-24': -8480.0, 'Sensor-25': -1109.25, 'Sensor-26': 1.3255, 'Sensor-27': 1.9918, 'Sensor-28': 7.2343, 'Sensor-29': 72.4889, 'Sensor-30': 2.5111, 'Sensor-31': 0.2049, 'Sensor-32': 3.3309, 'Sensor-33': 85.9625, 'Sensor-34': 8.7552, 'Sensor-35': 50.1251, 'Sensor-36': 64.1204, 'Sensor-37': 49.8749, 'Sensor-38': 66.2133, 'Sensor-39': 86.438, 'Sensor-40': 120.4374, 'Sensor-41': 78.72, 'Sensor-42': 3.074, 'Sensor-43': 70, 'Sensor-44': 363.6891, 'Sensor-45': 10.297, 'Sensor-46': 128.6345, 'Sensor-47': 731.9676, 'Sensor-48': 1.0905, 'Sensor-49': 141.6718, 'Sensor-50': 1, 'Sensor-51': 633.9955, 'Sensor-52': 59.3627, 'Sensor-53': 0, 'Sensor-54': 4.463, 'Sensor-55': 4.711, 'Sensor-56': 2915, 'Sensor-57': 0.9082, 'Sensor-58': 0.9473, 'Sensor-59': 4.5341, 'Sensor-60': 4.4209, 'Sensor-61': 361.1209, 'Sensor-62': 10.8385, 'Sensor-63': 113.0555, 'Sensor-64': 11.7637, 'Sensor-65': 15.5791, 'Sensor-66': 19.1247, 'Sensor-67': 712.8429, 'Sensor-68': 1.0056, 'Sensor-69': 148.0555, 'Sensor-70': 1, 'Sensor-71': 622.2318, 'Sensor-72': 123.7995, 'Sensor-73': None, 'Sensor-74': None, 'Sensor-75': 0.0, 'Sensor-76': -0.0446, 'Sensor-77': 0.0051, 'Sensor-78': -0.0449, 'Sensor-79': -0.0197, 'Sensor-80': 0.0019, 'Sensor-81': -0.0432, 'Sensor-82': -0.012, 'Sensor-83': -0.0675, 'Sensor-84': 7.7328, 'Sensor-85': 0.1329, 'Sensor-86': None, 'Sensor-87': 2.4398, 'Sensor-88': 0.9903, 'Sensor-89': 1777.6835, 'Sensor-90': None, 'Sensor-91': None, 'Sensor-92': -0.0417, 'Sensor-93': -0.0039, 'Sensor-94': -0.0009, 'Sensor-95': -0.0001, 'Sensor-96': 0.0001, 'Sensor-97': 0.0951, 'Sensor-98': 0, 'Sensor-99': -0.3678, 'Sensor-100': 0.1302, 'Sensor-101': 0.0003, 'Sensor-102': -0.0002, 'Sensor-103': -0.0312, 'Sensor-104': -0.0091, 'Sensor-105': -0.0017, 'Sensor-106': 0.0039, 'Sensor-107': 0.0009, 'Sensor-108': -0.1536, 'Sensor-109': -0.0643, 'Sensor-110': 0.9833, 'Sensor-111': 102.2536, 'Sensor-112': 231.0861, 'Sensor-113': None, 'Sensor-114': 0.9565, 'Sensor-115': 0.0, 'Sensor-116': 773.9208, 'Sensor-117': 0.9899, 'Sensor-118': 56.0862, 'Sensor-119': 0.6048, 'Sensor-120': 0.9665, 'Sensor-121': 6.3101, 'Sensor-122': 15.74, 'Sensor-123': 4.775, 'Sensor-124': 15.8, 'Sensor-125': 15.77, 'Sensor-126': 1.461, 'Sensor-127': 2.671, 'Sensor-128': 0.8019, 'Sensor-129': 3.259, 'Sensor-130': -0.0946, 'Sensor-131': 0.6595, 'Sensor-132': 0.9965, 'Sensor-133': 2.2453, 'Sensor-134': 1015.5533, 'Sensor-135': 39.983, 'Sensor-136': 102, 'Sensor-137': 82.6, 'Sensor-138': 105.8, 'Sensor-139': 32.3999, 'Sensor-140': 1635.3, 'Sensor-141': 0.3124, 'Sensor-142': 0.0, 'Sensor-143': 9.59, 'Sensor-144': 0.0019, 'Sensor-145': 0.0793, 'Sensor-146': 0.0416, 'Sensor-147': 0.0698, 'Sensor-148': 0.0203, 'Sensor-149': 6.7384, 'Sensor-150': 0, 'Sensor-151': 5.245, 'Sensor-152': 11.651, 'Sensor-153': 0.4086, 'Sensor-154': 0.0123, 'Sensor-155': 6.3958, 'Sensor-156': 0.24, 'Sensor-157': 0.0384, 'Sensor-158': None, 'Sensor-159': None, 'Sensor-160': 1264, 'Sensor-161': 466, 'Sensor-162': 12643, 'Sensor-163': 2148, 'Sensor-164': 0.13, 'Sensor-165': 0.088, 'Sensor-166': 0.316, 'Sensor-167': 3.8, 'Sensor-168': 1.0, 'Sensor-169': 0.089, 'Sensor-170': 0.623, 'Sensor-171': 0.7793, 'Sensor-172': 0.0421, 'Sensor-173': 0.2656, 'Sensor-174': 0.4885, 'Sensor-175': 0.2656, 'Sensor-176': 0.6352, 'Sensor-177': 0.249, 'Sensor-178': 0.454, 'Sensor-179': 0, 'Sensor-180': 0, 'Sensor-181': 25.47, 'Sensor-182': 1.097, 'Sensor-183': 15.64, 'Sensor-184': 15.431, 'Sensor-185': 0.2066, 'S ...

# %%
mongouser='rahul95'
mongopasswd='rahul123'
str='pymongo.MongoClient("mongodb+srv://{}:{}@python-mongo.enkic.mongodb.net/waferFaultDB?retryWrites=true&w=majority'.format(mongouser,mongopasswd)

# %%
client.list_database_names()
# Out:
# ['test', 'waferFaultDB', 'admin', 'local']

# %%
client.close()
